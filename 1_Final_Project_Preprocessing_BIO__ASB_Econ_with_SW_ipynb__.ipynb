# %% [markdown]
# # Предварительная обработка текстовых данных перед их передачей в модели Machine Learning.

# %% [markdown]
# ## Первый корпус (*BIOcorpus*) базируется на материале 251 научной статьи разного типа (research article, review article), которые были опубликованы в период с 2010 по 2019 гг., из междисциплинарных и специализированных периодических журналов по 7 дисциплинарным направлениям (биохимия, биофизика, биотехнология/биоинженерия, клеточная биология, генетика, гидробиология, молекулярная биология).
#
# * Предобработка медико-биологических текстов требует особого подхода из-за превалирования в них специальной терминологии, часто представленной цепочками число-буквенных последовательностей и/или аббревиатур.

# %% [markdown]
# ## Для предобработки текстов BIOcorpus была использована модель scispaCy, созданная специально для обработки медико-биологических текстов (малая модель для 100тыс. словарных ед). Также был использован EntityLinker - компонент SpaCy, который выполняет связывание с базой знаний (в нашем случае с  the Unified Medical Language System, содержащей ~3M концептов. Linker  выполняет поиск  именованных сущностей (от char до 3grams), сравнивая их с концепциями в базе знаний с помощью алгоритма поиска ближайших соседей.
#
# https://github.com/allenai/scispacy
#
# Neumann, M., King, D., Beltagy, I., Ammar, W. (2019). ScispaCy: Fast and Robust Models for
# Biomedical Natural Language Processing, Proceedings of the 18th BioNLP Workshop and Shared Task (pp. 319–327), Florence: Association for Computational Linguistics.

# %%
! pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz
#   Downloading https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz (14.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 32.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.8.0,>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from en-core-sci-sm==0.5.4) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (8.2.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.1.2)
# Building wheels for collected packages: en-core-sci-sm
#   Building wheel for en-core-sci-sm (setup.py) ... done
#   Created wheel for en-core-sci-sm: filename=en_core_sci_sm-0.5.4-py3-none-any.whl size=14778490 sha256=5bfbb75bc5d4f219409ae926b8e2bada3227beac940f8e478ce88dfe02a05877
#   Stored in directory: /root/.cache/pip/wheels/0e/d3/6e/e03165bcf8c0fe90c7a41e8a44dd268e4c7779582c5e022707
# Successfully built en-core-sci-sm
# Installing collected packages: en-core-sci-sm
# Successfully installed en-core-sci-sm-0.5.4

# %%
! pip install scispacy
# Out:
# Collecting scispacy
#   Downloading scispacy-0.5.4-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 865.1 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from scispacy) (3.7.5)
# Collecting scipy<1.11 (from scispacy)
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scispacy) (2.31.0)
# Collecting conllu (from scispacy)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scispacy) (1.25.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scispacy) (1.4.2)
# Collecting nmslib>=1.7.3.6 (from scispacy)
#   Downloading nmslib-2.1.1.tar.gz (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 kB 22.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.10/dist-packages (from scispacy) (1.2.2)
# Collecting pysbd (from scispacy)
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 10.4 MB/s eta 0:00:00
# Collecting pybind11<2.6.2 (from nmslib>=1.7.3.6->scispacy)
#   Using cached pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from nmslib>=1.7.3.6->scispacy) (5.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2024.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.3->scispacy) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (8.2.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (4.66.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (4.12.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->scispacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (0.1.2)
# Building wheels for collected packages: nmslib
#   Building wheel for nmslib (setup.py) ... done
#   Created wheel for nmslib: filename=nmslib-2.1.1-cp310-cp310-linux_x86_64.whl size=13578731 sha256=729eeb52dd9364cc7c2c495ce9c0ed0b8900739de1c82a769f57dbdfc23bc055
#   Stored in directory: /root/.cache/pip/wheels/21/1a/5d/4cc754a5b1a88405cad184b76f823897a63a8d19afcd4b9314
# Successfully built nmslib
# Installing collected packages: scipy, pysbd, pybind11, conllu, nmslib, scispacy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
# Successfully installed conllu-4.5.3 nmslib-2.1.1 pybind11-2.6.1 pysbd-0.3.4 scipy-1.10.1 scispacy-0.5.4

# %%
# Функция для подсчета словоупотреблений в корпусе
def count_words(df):
    w = 0
    for idx, row in df.iterrows():
        w += len(row['text'].split())
    return w

# %%
import scispacy.linking
import scispacy
import spacy

import pandas as pd
import numpy as np

import re
import string
import nltk
from nltk.corpus import stopwords

nltk.download("stopwords")
stops = stopwords.words("english")

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nlp = spacy.load("en_core_sci_sm")
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2023-04-23/umls/tfidf_vectors_sparse.npz not found in cache, downloading to /tmp/tmpe4mbq0ca
# 100%|██████████| 492M/492M [00:12<00:00, 39.9MiB/s]
# Finished download, copying /tmp/tmpe4mbq0ca to cache at /root/.scispacy/datasets/2b79923846fb52e62d686f2db846392575c8eb5b732d9d26cd3ca9378c622d40.87bd52d0f0ee055c1e455ef54ba45149d188552f07991b765da256a1b512ca0b.tfidf_vectors_sparse.npz
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2023-04-23/umls/nmslib_index.bin not found in cache, downloading to /tmp/tmpw_vzn1yn
# 100%|██████████| 724M/724M [00:33<00:00, 22.7MiB/s]
# Finished download, copying /tmp/tmpw_vzn1yn to cache at /root/.scispacy/datasets/7e8e091ec80370b87b1652f461eae9d926e543a403a69c1f0968f71157322c25.6d801a1e14867953e36258b0e19a23723ae84b0abd2a723bdd3574c3e0c873b4.nmslib_index.bin
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2023-04-23/umls/tfidf_vectorizer.joblib not found in cache, downloading to /tmp/tmp1t8y9nay
# 100%|██████████| 1.32M/1.32M [00:00<00:00, 3.31MiB/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Finished download, copying /tmp/tmp1t8y9nay to cache at /root/.scispacy/datasets/37bc06bb7ce30de7251db5f5cbac788998e33b3984410caed2d0083187e01d38.f0994c1b61cc70d0eb96dea4947dddcb37460fb5ae60975013711228c8fe3fba.tfidf_vectorizer.joblib
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2023-04-23/umls/concept_aliases.json not found in cache, downloading to /tmp/tmpqciibawn
# 100%|██████████| 264M/264M [00:07<00:00, 36.8MiB/s]
# Finished download, copying /tmp/tmpqciibawn to cache at /root/.scispacy/datasets/6238f505f56aca33290aab44097f67dd1b88880e3be6d6dcce65e56e9255b7d4.d7f77b1629001b40f1b1bc951f3a890ff2d516fb8fbae3111b236b31b33d6dcf.concept_aliases.json
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/kbs/2023-04-23/umls_2022_ab_cat0129.jsonl not found in cache, downloading to /tmp/tmp_42sg0fq
# 100%|██████████| 628M/628M [00:55<00:00, 11.9MiB/s]
# Finished download, copying /tmp/tmp_42sg0fq to cache at /root/.scispacy/datasets/d5e593bc2d8adeee7754be423cd64f5d331ebf26272074a2575616be55697632.0660f30a60ad00fffd8bbf084a18eb3f462fd192ac5563bf50940fc32a850a3c.umls_2022_ab_cat0129.jsonl
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/umls_semantic_type_tree.tsv not found in cache, downloading to /tmp/tmpp045ylzg
# 100%|██████████| 4.26k/4.26k [00:00<00:00, 8.76MiB/s]
# Finished download, copying /tmp/tmpp045ylzg to cache at /root/.scispacy/datasets/21a1012c532c3a431d60895c509f5b4d45b0f8966c4178b892190a302b21836f.330707f4efe774134872b9f77f0e3208c1d30f50800b3b39a6b8ec21d9adf1b7.umls_semantic_type_tree.tsv

# %% [markdown]
# ## При обработке текста с помощью sciscpaCy стало очевидно, насколько значительную часть академического текста составляют термины: текст сокращался приблизительно в 4 раза, оставляя практически голый скелет из служебных слов и редких ЛЕ литературного языка. Это связано с тем, что многие так называемые общенаучные / академические ЛЕ в научных текстах приобретают особую семантику, а также входят в состав терминологических единиц, являясь "субстратом" для создания новых терминов (В.М.Лейчик). Таким образом, было решено удалять термины, оставляя при этом академические слова, даже входящие в терминологические единицы. В качестве списка академических слов был взят AVL (D.Gardner, M.Davies, 2013), состоящий из 1992 академических ЛЕММ, к которому  при помощи Wordnet были добавлены словообразовательные гнезда, что позволило увеличить список "оставляемых" слов до 4634 ЛЕ.

# %%
# Достаём академические слова из файла:
words = ''
with open("AVL.txt", 'r') as f:
    for line in f:
        words += line
words = re.sub(r'\s', ' ', words)
words = set(words.split(' '))
len(words)
# Out:
# 1992

# %%
from nltk.corpus import wordnet as wn

# Добавляем к каждому слову списка "словарные гнезда", т. е. совокупности слов, обладающих общностью корня(например, indicate - indicating, indication и т.д.)
def add_words_derivations(words):
    forms = set()
    for word in words:
        # We'll store the derivational forms in a set to eliminate duplicates
        for happy_lemma in wn.lemmas(word): #for each "happy" lemma in WordNet
            forms.add(happy_lemma.name()) #add the lemma itself
            for related_lemma in happy_lemma.derivationally_related_forms(): #for each related lemma
                forms.add(related_lemma.name()) #add the related lemma
    return forms

nltk.download('wordnet')
words = add_words_derivations(words)
print(len(words))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# 4634

# %%
def remove_biology_terms(text):
    text = re.sub(r'\s', ' ', text)

    doc = nlp(text)
    doc_no_ents = []
    ents = list(set([e.text for e in doc.ents]) - words)

    ents_one_word = [ent for ent in ents if len(ent.split(' ')) == 1]
    ents_two_words = [ent for ent in ents if len(ent.split(' ')) == 2]
    ents_three_words = [ent for ent in ents if len(ent.split(' ')) == 3]
    ents_four_words = [ent for ent in ents if len(ent.split(' ')) == 4]

    i = 0
    while i < len(doc):
        #удаление медицинских терминов, состоящих из 1, 2, 3 и 4 слов соответственно:
        if  doc[i].text in ents_one_word:
            i += 1
            continue
        if (i + 1 < len(doc)) and (doc[i].text + ' ' + doc[i + 1].text in ents_two_words):
            i += 2
            continue
        if (i + 2 < len(doc)) and (doc[i].text + ' ' + doc[i + 1].text + ' ' + doc[i + 2].text in ents_three_words):
            i += 3
            continue
        if (i + 3 < len(doc)) and (doc[i].text + ' ' + doc[i + 1].text + ' ' + doc[i + 2].text + ' ' + doc[i + 3].text in ents_four_words):
            i += 4
            continue

        #удаление стоп-слов (зависит от задачи):
        #if doc[i].text.lower() in stops:
           # i += 1
           # continue

        doc_no_ents.append(doc[i].text)
        i += 1
    return " ".join(doc_no_ents)

# %%
# Разбиваем тексты на предложения
def sent_split(df, col):
    sents = []
    for _, row in df.iterrows():
        text = row[col]
        for sent in nltk.sent_tokenize(text):
            sents.append(sent)
    sents = pd.DataFrame(sents).rename({0: 'text'}, axis=1)
    return sents

# %%
# NB! Стоит обратить внимание на последовательность действий:
def cleantext(df):
    # удаляем имена из одной буквы и точки
    df['cleaned_text'] = df['text'].replace(r'[A-Z]\.', "", regex=True)

    # приводим к нижнему регистру
    df['cleaned_text'] = df['cleaned_text'].str.lower()

    # Внутритекстовые ссылки в квадратных скобках
    df['cleaned_text'] = df['cleaned_text'].replace(r'\[[0-9 ,– -]+\]', "", regex=True) # от ссылок в квадратных скобках внутри текста

    # Удаление дефиса
    df['cleaned_text'] = df['cleaned_text'].replace(r"-\n", "", regex = True)

    # удаляем всё, кроме заглавных и строчных букв английского алфавита
    df['cleaned_text'] = df['cleaned_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)

    # Удаление doi | DOI
    df['cleaned_text'] = df['cleaned_text'].replace(r'(/doi/10[.][0-9]{4,}.*)', '', regex=True)

    # удаляем возможные ссылки URL(x):
    df['cleaned_text']  = df['cleaned_text'].replace(r'https.*', "", regex = True)

    # Удаление цифр
    df['cleaned_text'] = df['cleaned_text'].replace(r'\d+', '', regex=True)

    # Удаление двух и более подряд идущих пробелов
    df['cleaned_text'] = df['cleaned_text'].replace(r'\s{2,}', ' ', regex=True)
    return df

# %%
# Для работы с моделями Bert, которые принимают на вход предложения одной длины (512 токенов по умолчанию)
def clean_long_sent(df):
    df["len"] = df["cleaned_text"].apply(lambda x: len(x))
    return df[df.len <= 512]

# %% [markdown]
# # Биологический текст

# %%
bio = pd.read_csv("/content/BIOcorpus.csv")
bio
# Out:
#      Unnamed: 0                                               text  \
# 0             0  bs_bs_banner\n\nINVITED REVIEW SERIES:\nSTEM C...
# 1             1  AIMS Bioengineering, 5(1): 1–38. \n\nDOI: 10.3...
# 2             2  Leuba et al. BMC Biophysics 2014, 7:6\nhttp://...
# 3             3  Hydrobiologia (2019) 836:35–47\nhttps://doi.or...
# 4             4  Woods BMC Biophysics 2014, 7:8\nhttp://www.bio...
# ..          ...                                                ...
# 246         246  J. Biochem. 2019;166(1):97–106 doi:10.1093/jb/...
# 247         247  Smith et al. BMC Molecular Biol  (2016) 17:22 ...
# 248         248  Protein Engineering, Design & Selection vol. 2...
# 249         249  Protein Engineering, Design & Selection vol. 2...
# 250         250  Volume 2, Issue 3, 249-263. \nDOI: 10.3934/bio...
#
#                               branch
# 0                    CELL BIOLOGY 18
# 1    BIOTECHNOLOGY:BIOENGINEERING 18
# 2                      BIOPHYSICS 28
# 3                    HYDROBIOLOGY 11
# 4                      BIOPHYSICS 29
# ..                               ...
# 246                  BIOCHEMISTRY 36
# 247              MOLECULAR BIOLOGY 2
# 248  BIOTECHNOLOGY:BIOENGINEERING 23
# 249  BIOTECHNOLOGY:BIOENGINEERING 35
# 250   BIOTECHNOLOGY:BIOENGINEERING 9
#
# [251 rows x 3 columns]

# %% [markdown]
# ## Немного разбираемся с регулярками

# %%
import re
re.findall(r'\[[0-9 ,– -]+\]', bio["text"].iloc[1])
# [0-9 ,– -] -- набор символов, который мы ищем
# [0-9 ,– -]+ -- любой из символов встречается хотя бы 1 раз ("abcd6 9-,1" -> "6 9-,1")
# \[[0-9 ,– -]+\] -- ищем строчки из п.2 в квадратных скобках, \ -- символ экранирования
# Out:
# ['[1,2]',
#  '[3]',
#  '[4]',
#  '[5]',
#  '[6]',
#  '[6]',
#  '[7]',
#  '[1]',
#  '[8]',
#  '[1]',
#  '[6]',
#  '[1]',
#  '[6]',
#  '[9]',
#  '[10]',
#  '[2]',
#  '[11]',
#  '[2]',
#  '[10]',
#  '[4]',
#  '[4]',
#  '[4]',
#  '[12]',
#  '[13]',
#  '[14]',
#  '[3]',
#  '[15]',
#  '[3]',
#  '[16]',
#  '[17]',
#  '[18]',
#  '[19]',
#  '[20]',
#  '[4]',
#  '[21,22]',
#  '[21]',
#  '[23]',
#  '[24]',
#  '[24]',
#  '[25]',
#  '[5]',
#  '[26]',
#  '[27]',
#  '[28]',
#  '[29]',
#  '[30]',
#  '[31]',
#  '[32]',
#  '[5]',
#  '[33]',
#  '[34]',
#  '[34]',
#  '[5,35]',
#  '[36,37]',
#  '[38,39]',
#  '[40,41]',
#  '[30]',
#  '[42]',
#  '[43]',
#  '[44]',
#  '[45]',
#  '[44,46]',
#  '[47]',
#  '[48]',
#  '[49]',
#  '[50]',
#  '[51]',
#  '[47,52]',
#  '[47]',
#  '[53,54]',
#  '[47,55–57]',
#  '[58,59]',
#  '[60]',
#  '[61,62]',
#  '[61,62]',
#  '[63,64]',
#  '[57]',
#  '[65]',
#  '[66–68]',
#  '[69,70]',
#  '[71]',
#  '[72]',
#  '[73]',
#  '[72]',
#  '[74]',
#  '[75,76]',
#  '[63,64]',
#  '[77]',
#  '[78]',
#  '[79]',
#  '[80]',
#  '[81]',
#  '[63]',
#  '[82]',
#  '[82,83]',
#  '[83–85]',
#  '[85]',
#  '[86,87]',
#  '[88]',
#  '[89]',
#  '[88]',
#  '[90]',
#  '[90]',
#  '[79]',
#  '[91]',
#  '[90]',
#  '[90]',
#  '[92]',
#  '[92]',
#  '[91]',
#  '[93]',
#  '[87]',
#  '[93]',
#  '[91]',
#  '[91]',
#  '[35,94]',
#  '[35]',
#  '[35,83]',
#  '[27]',
#  '[95]',
#  '[83]',
#  '[96]',
#  '[97]',
#  '[83]',
#  '[35]',
#  '[96]',
#  '[79,80,83,85,92,93,96,98,99]',
#  '[98]',
#  '[85]',
#  '[92]',
#  '[79]',
#  '[96]',
#  '[96]',
#  '[35,94]',
#  '[94,100]',
#  '[94]',
#  '[100]',
#  '[27,28,101]',
#  '[100]',
#  '[102]',
#  '[103,104]',
#  '[105]',
#  '[106]',
#  '[107]',
#  '[108]',
#  '[109,110]',
#  '[93]',
#  '[96]',
#  '[96]',
#  '[96]',
#  '[96]',
#  '[96]',
#  '[27]',
#  '[84,105]',
#  '[111]',
#  '[112]',
#  '[113–115]',
#  '[116]',
#  '[48,117,118]',
#  '[113]',
#  '[91]',
#  '[116]',
#  '[50]',
#  '[119]',
#  '[120]',
#  '[61,62]',
#  '[121]',
#  '[90]',
#  '[122]',
#  '[90]',
#  '[85]',
#  '[122]',
#  '[90]',
#  '[90]',
#  '[35]',
#  '[92]',
#  '[80]',
#  '[123]',
#  '[124]',
#  '[32]',
#  '[125]',
#  '[123]',
#  '[35]',
#  '[126]',
#  '[126]',
#  '[90]',
#  '[127]',
#  '[127]',
#  '[98]',
#  '[98]',
#  '[99]',
#  '[85]',
#  '[85]',
#  '[83]',
#  '[83]',
#  '[35]',
#  '[35]',
#  '[35]',
#  '[92]',
#  '[121]',
#  '[93]',
#  '[93]',
#  '[93]',
#  '[79]',
#  '[79]',
#  '[91]',
#  '[91]',
#  '[80]',
#  '[96]']

# %%
for i in range(len(bio)):
    if len(re.findall(r'https.*', bio['text'].iloc[i])) > 0:
        print(re.findall(r'https.*', bio['text'].iloc[i]))

# https. -- ищем подстроку "https{любой символ кроме начала строки}"
# https.* -- ищем подстроку "https{все символы кроме начала строки}"
# https.*$ -- ищем подстроку "https{все символы кроме начала строки}",  которая заканчивается символом конца строки
# Out:
# ['https://doi.org/10.1007/s10750-019-3939-2 (0123456789().,-volV)(0123456789().,-volV)', 'https://doi.org/10.1007/s10750-019-3939-2) con-']
# ['https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).', 'https://doi.org/10.1083/jcb.201707168', 'https ://doi .org /10 .1093 /molehr /gap092', 'https ://doi .org /10 .1093 /hmg /ddp483', 'https ://doi .org ', 'https ://doi .org /10 .1042 /BST20110609', 'https ://doi .org /10 .1016 /j .exger .2012 .09 .009', 'https ://doi ', 'https ://doi .org /10 .1126 /science .1065768', 'https ://doi .org /10 .1016 /', 'https ://doi .org /10 .1111 /j .1474 -9726 .2007 .00348 .x', 'https ://doi .org /10 .1016 /j .cell .2006 .01 .039', 'https ://doi ', 'https ://doi .org /10 .1126 /science .1078223', 'https ://doi .org /10 ', 'https ://doi .org /10 .18632 /', 'https ://doi ', 'https ://doi .org ', 'https ', 'https ://doi .org /10 .1016 /S0092 -8674(00)80595 ', 'https ://doi .org /10 .1126 /science .289 .5487 .2122', 'https ://doi .org /10 .1126 /science .277 .5322 .99', 'https ://doi .org /10 ', 'https ://doi .org /10 .1038 /35030105', 'https ://doi .org /10 ', 'https ://doi .org /10 .1046 /j .1474 -9728 .2003 .00049 .x', 'https ://doi .org /10 .1126 /science ', 'https ://doi ', 'https ://doi .org /10 .1074 /jbc .M114 ', 'https ://doi ', 'https ://doi .org /10 .1126 /science .1057991', 'https ://doi .org /10 .1017 ', 'https ://doi .org /10 ', 'https ://doi .org ', 'https ://doi .org ', 'https ://doi .org /10 .1016 /S1047 ', 'https ://doi .org /10 .1002 /mrd .22806', 'https ://doi ', 'https ://doi .org /10 .1038 /', 'https ://doi .org /10 .1371 /journal .pgen .1004225', 'https ://doi .org /10 .1073 /pnas ', 'https ://doi .org /10 .1073 /pnas .0709128105', 'https ://doi .org /10 ', 'https ://', 'https ://doi .org /10 .1016 ', 'https ://doi .org /10 .2174 /157339913804143225', 'https ://doi .org /10 .1242 /bio ', 'https ://doi .org /10 .1016 /j .fertnstert .2015 .03 .030', 'https ://doi .org /10 ', 'https ://doi .org /10 .1126 /', 'https ://doi .org /10 ', 'https ://doi .org /10 .1126 /science .1098219', 'https ://doi .org /10 .1101 /gad .13 .11 .1422', 'https ://doi .org /10 .1038 /nature08619', 'https ://doi .org /10 .1016 /j .cub .2007 .08 .047', 'https ://doi .org /10 .1074 /jbc .M705325200', 'https ://doi .org /10 .1371 /', 'https ', 'https ://doi .org /10 .1093 /hmg /ddh241', 'https ://doi .org /10 .1111 /j ', 'https ://doi .org /10 .1038 /nrm3311', 'https ://doi .org /10 .1016 /j .tcb .2015 .10 .013', 'https ://doi ', 'https ://doi .org /10 .1073 /pnas ', 'https ://doi .org /10 .1038 ', 'https ://doi .org /10 .1073 /pnas ', 'https ://doi .org /10 .1126 /science .1083701', 'https ://doi .org /10 ', 'https ://doi .org /10 .1371 /journal .pgen .0030025', 'https ://doi .org /10 .1038 /nature02549', 'https ://doi .org /10 .1073 /pnas .0710787105', 'https ://doi .org /10 .1038 /ncb839', 'https ://doi .org /10 ', 'https ://doi .org /10 .1016 /j .annepidem .2014 .12 .002', 'https ://doi .org /10 ', 'https ://doi .org ', 'https ', 'https ://doi .org /10 .1016 /j .cub ', 'https ://doi .org /10 .1371 ', 'https ', 'https ', 'https ://doi .org /10 .1038 /ncb2152', 'https ://doi .org /10 .1016 /0047 -6374(77)90043 -4', 'https ://doi .org /10 .1016 /j .exger .2004 .05 ', 'https ://doi .org /10 .1242 /dev .074047', 'https ://doi .org /10 .1126 /science .1111410', 'https ://', 'https ://doi .org /10 .1073 /pnas .95 .22 .13091', 'https ://doi .org /10 ', 'https ://doi .org /10 .1016 /j .cell .2012 .03 .017', 'https ://doi .org /10 ', 'https ://doi .org /10 .1093 /hmg /ddp459', 'https ', 'https ://doi .org /10 ', 'https ://doi .org /10 .1038 ', 'https ://', 'https ://doi .org /10 .1016 /j ', 'https ://doi .org ', 'https ://doi .org /10 .1111 /j .1558 -5646 .1984 .tb00369 .x', 'https ://doi .org /10 .1186 /1471 -2350 -8 ', 'https ://doi .org /10 .1371 /journal .pgen .1000789', 'https ://doi .org /10 ', 'https ', 'https ://doi .org ', 'https ://doi .org /10 .1016 /j .cub .2008 .06 .059', 'https ://doi .org /10 .1016 /S1097 -2765(02)00568 -3', 'https ://doi .org /10 .1038 /nature11432', 'https ://doi .org /10 .1095 /', 'https ://', 'https ://doi .org ...
# ['https://doi.org/10.1186/s12863-019-0718-z', 'https://grenada.-', 'https://grenada.lumc.nl/LSDB_list/', 'https://www.gwascentral.org) is also available,', 'https://databases.lovd.nl/shared/genes/NR3C1), Lei-', 'https://www.ncbi.nlm.nih.gov/books/NBK269031/. Accessed 3 Mar 2017.', 'https://www.ncbi.nlm.nih.gov/books/NBK3848/.']
# ['https:// creativecommons .org/ licenses/ by/ 4 .0/ ).', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https://doi.org/10.1083/jcb.201808014', 'https:// doi .org/ 10 .1016/ S0092 -8674(01)00410 -X', 'https:// doi .org/ 10 .1038/ nature19083', 'https:// doi .org/ 10 .1083/ ', 'https:// doi .org/ 10 .1083/ jcb .201008108', 'https:// doi .org/ 10 .1128/ MCB .06525 -11', 'https:// doi .org/ 10 .1038/ nprot .2009 .21', 'https:// doi .org/ 10 .1073/ pnas .0914191107', 'https:// doi .org/ 10 .1091/ mbc .e09 -07 -0643', 'https:// doi .org/ 10 .1016/ j .cell .2006 ', 'https:// doi .org/ 10 .1021/ jacs .7b09368', 'https:// doi .org/ 10 .1038/ 10049', 'https:// doi .org/ 10 .1038/ ncb2855', 'https:// doi .org/ 10 .1021/ ', 'https:// ', 'https:// doi .org/ 10 .1083/ jcb .201606033', 'https:// doi .org/ 10 .1101/ gad .267603', 'https:// doi .org/ 10 .1083/ jcb .201205119', 'https:// doi .org/ 10 .1016/ j .cell .2006 ', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 .1371/ ', 'https:// doi .org/ 10 .1073/ pnas .91 ', 'https:// doi .org/ 10 .1371/ journal .pone .0018793', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 .1083/ jcb .201406109', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 .1038/ nrm3494', 'https:// doi .org/ 10 .1038/ ', 'https:// doi .org/ 10 .1083/ jcb .201301006', 'https:// doi .org/ 10 .1126/ science .1197048', 'https:// ', 'https:// doi .org/ 10 .1073/ pnas ', 'https:// doi .org/ 10 .1038/ ncb3634', 'https://doi.org/10.1083/jcb.201808014', 'https:// doi .org/ 10 .1126/ science .1163300', 'https:// doi .org/ 10 .1126/ science ', 'https:// doi .org/ 10 .1016/ j .cub .2009 .02 ', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 .1083/ jcb .201003038', 'https:// doi .org/ 10 .1126/ science .aaa4029', 'https:// doi .org/ 10 .7554/ eLife .22513', 'https:// doi ', 'https:// doi .org/ 10 .1038/ ncb3065', 'https:// doi .org/ 10 .1038/ ncb0707 -724', 'https:// doi .org/ 10 .1038/ 344503a0', 'https:// doi .org/ 10 .7554/ eLife .01030', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 .1016/ j .cub .2014 .01 .033', 'https:// doi .org/ 10 .1016/ j .celrep .2014 .02 .034', 'https:// doi .org/ ', 'https:// doi .org/ 10 .1016/ j .cub .2014 .02 .020', 'https:// doi .org/ 10 .1242/ jcs .122481', 'https:// doi .org/ 10 .1073/ ', 'https:// doi .org/ 10 .1038/ emboj ', 'https:// doi .org/ 10 .1016/ j .tcb .2010 .10 .007', 'https:// doi .org/ 10 .1146/ annurev -biochem -061611 ', 'https:// doi .org/ 10 .1091/ ', 'https:// doi .org/ 10 .1016/ j .cub .2012 .03 .052', 'https:// doi .org/ 10 .1016/ j .ccr .2010 .10 .028', 'https:// doi .org/ 10 .1126/ science .1195689', 'https:// doi .org/ 10 .1016/ j .cub .2011 .12 .048', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 .1038/ nmeth .2019', 'https:// doi .org/ 10 .1016/ ', 'https:// doi .org/ 10 .1038/ nrm3934', 'https:// doi .org/ 10 .1016/ j .celrep .2016 .01 .045', 'https:// doi .org/ 10 .1093/ emboj/ 21 .7 ', 'https:// doi .org/ 10 .1007/ s00412 -004 -0288 -2', 'https:// doi ', 'https:// doi .org/ 10 .1083/ jcb .200712028', 'https:// doi .org/ 10 .1038/ nature09390', 'https:// doi .org/ 10 .1016/ j .cub .2010 ', 'https:// doi .org/ 10 .1042/ ', 'https:// doi .org/ 10 .1038/ 35048096', 'https://doi.org/10.1083/jcb.201808014', 'https:// doi .org/ 10 .1016/ j .cub .2014 .01 ', 'https:// doi ', 'https:// doi .org/ 10 .1128/ MCB .00753 -10', 'https:// doi .org/ 10 .1016/ j .febslet .2015 .02 ', 'https:// doi .org/ 10 .4161/ cc .9 .17 .12832', 'h ...
# ['https://github.com/joey711/phyloseq).']
# ['https://doi.org/10.1083/jcb.201705214', 'https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).', 'https ://doi .org /10 .1016 /j .semcdb .2009 .03 .007', 'https ://doi .org /10 .1038 /nrm2999', 'https ://doi .org /10 .1016 /j .cell .2013 .01 .030', 'https ://doi .org /10 ', 'https ://doi .org /10 ', 'https ://doi .org /10 ', 'https ://doi .org /10 .4161 ', 'https ://doi .org /10 .1111 /tra .12095', 'https ://doi .org /10 .1038 /', 'https ://doi .org /10 ', 'https ://doi .org /10 .1091 /mbc .E14 -04 -0917', 'https ://doi .org /10 .1111 /j .1600 -0854 .2011 .01181 .x', 'https ://doi .org /10 .1534 /genetics ', 'https ://doi .org /10 .1016 /j .devcel .2017 .03 .015', 'https ://doi .org /10 .1016 ', 'https ://doi .org /10 .1016 /j .molcel .2008 .07 .020', 'https ://doi .org /10 .1093 /', 'https ://doi .org /10 .1074 /jbc .M112 .411454', 'https ', 'https ://doi .org /10 .3389 /fcell ', 'https ://doi .org /10 .1083 /jcb .200901145', 'https ://doi .org /10 ', 'https ://doi .org /10 .1091 ', 'https ://doi .org /10 .4161 /21592780 .2014 .954870', 'https ://doi .org /10 ', 'https ://doi .org /10 .1091 /mbc .E13 -05 -0269', 'https ://doi .org /10 .1534 /genetics .116 .194910', 'https ://doi .org /10 ', 'https ://doi .org /10 .1073 /pnas ', 'https ://doi .org /10 .1016 /j .devcel .2014 .07 .016', 'https ://doi .org /10 .1074 /jbc ', 'https ://doi .org /10 .1016 ', 'https ://doi .org /10 .1111 /j ', 'https ://doi .org /10 .1038 /ncb1489', 'https ://doi .org /10 .1042 /', 'https ://doi .org /10 .1083 /jcb .115 .1 .31', 'https ://doi .org /10 .1016 /j .devcel .2012 .02 .006', 'https ://doi .org /10 .1073 /pnas ', 'https ://doi .org /10 .1093 /', 'https ://doi .org /10 .1016 /', 'https ', 'https ://doi .org /10 .1016 /j .cell .2008 .06 .025', 'https ://doi .org /10 .1111 /j .1600 -0854 .2010 .01031 .x', 'https ://doi .org /10 .1091 /mbc .E10 -11 -0873', 'https ://doi .org /10 .1242 /jcs .131318', 'https ://doi .org /10 .1016 /j .febslet .2013 .05 .015', 'https ://doi .org /10 .1038 /nrm2728', 'https ://doi .org /10 .1073 /pnas .1308627110', 'https ://doi .org /10 .1083 /jcb .200111081', 'https ://doi .org /10 .1073 /pnas .1316356110', 'https ://doi .org /10 .1083 /jcb .201608123', 'https ://doi .org /10 .1083 /jcb .119 .4 .749', 'https ://doi .org /10 .1016 ', 'https ://doi .org ', 'https ://doi .org /10 ', 'https ://doi .org /10 ', 'https ://doi .org ', 'https ://doi .org /10 ', 'https ://doi .org /10 .1083 /jcb ', 'https ://doi .org /10 .1083 /jcb .200603044', 'https ://doi .org /10 .1038 /srep43207', 'https ://doi .org /10 .1111 ', 'https ://doi .org /10 ', 'https ://doi .org /10 ']
# ['https://labs.genetics.ucla.edu/horvath/dnamage/).']
# ['https://doi.org/10.1155/2017/7315351', 'https://www.hindawi.com']
# ['https://zenodo.org/record/45167,', 'https://zenodo.org/record/45168, https://zenodo.org/record/', 'https://zenodo.org/record/45196, https://zenodo.']
# ['https://doi.org/10.1007/s10750-019-3918-7 (0123456789().,-volV)(0123456789().,-volV)', 'https://doi.org/10.1007/s10750-019-3918-7) con-', 'https://toxics.usgs.gov/hypoxia/', 'https://data.gulfresearchinitiative.orgdata/R4.', 'https://doi.org/10.3133/', 'https://doi.org/10.1890/100008.', 'https://', 'https://doi.', 'https://doi.org/10.1007/s12237-016-', 'https://doi.org/10.3354/ame01607.']
# ['https://doi.org/10.1016/j.molcel.2017.12.007', 'https://doi.org/10.1016/j.molcel.2017.12.007', 'https://doi.org/', 'https://support.illumina.com/content/dam/illumina-support/', 'https://bitbucket.org/csmaxwell/crispr-txtl-pam-counting-script']
# ['https://doi.org/10.1007/s10750-019-3927-6 (0123456789().,-volV)(0123456789().,-volV)', 'https://doi.org/10.1139/cjfas-2018-']
# ['https://doi.org/10.1016/j.molcel.2018.07.017']
# ['https://doi.org/10.1007/s10750-018-3559-2']
# ['https://doi.org/10.1016/j.molcel.2019.05.023', 'https://doi.org/10.1016/j.molcel.2019.05.023', 'https://doi.org/10.1016/j.', 'https://usegalaxy.org', 'https://usegalaxy.org', 'https://usegalaxy.org', 'https://usegalaxy.org', 'https://usegalaxy.org', 'https://usegalaxy.org', 'https://usegalaxy.org', 'https://github.com/naomipetela/', 'https://github.com/naomipetela/', 'https://github.com/naomipetela/nasmythlab-ngs.']
# ['https://doi.org/10.1016/j.molcel.2018.08.002']
# ['https://doi.org/10.1007/s10750-018-3796-4 (0123456789().,-volV)(0123456789().,-volV)', 'https://doi.org/10.1007/s10750-018-3796-4) con-', 'https://github.com/', 'https://doi.org/10.5281/zenodo.1463690).', 'https://CRAN.']
# ['https://', 'https://www.aacc.org/publications/cln/articles/2014/april/cervical-cancer.', 'https://doi.org/10.6084/m9.ﬁgshare.3971883 (2016).']
# ['https://doi.org/10.1155/2018/9046891', 'https://imagej.nih.gov/ij/). The']
# ['https://doi.org/10.1007/s00249-018-1340-0']
# ['https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).', 'https://doi.org/10.1083/jcb.201612068']
# ['https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1136/bmj.329.7456.15', 'https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1001/jamainternmed.2017.3601', 'https://doi.org/10.1002/hep.28886', 'https://doi.org/10.7326/', 'https://doi.org/10.1016/j.bbamcr.2015.10.014', 'https://doi.org/10.1136/bmj.', 'https://doi.org/10.3791/50837', 'https://doi.org/10.1002/ar.', 'https://doi.org/10.1038/s41598-017-06433-3', 'https://doi.org/10.1002/sctm.16-0029', 'https://doi.org/10.1016/j.cell.2013.07.004', 'https://doi.org/10.1016/j.cell.2014.11.050', 'https://doi.org/10.1053/j.gastro.2011.09.001', 'https://doi.org/10.2131/jts.43.241', 'https://doi.org/10.1289/ehp.10727', 'https://doi.org/10.1089/adt.2015.659', 'https://doi.org/10.1038/4641116a', 'https://doi.org/10.1007/s40139-016-0113-7', 'https://doi.org/', 'https://doi.org/10.1172/JCI43122', 'https://doi.org/10.1007/', 'https://doi.org/10.1111/gtc.12101', 'https://doi.org/', 'https://doi.org/10.1016/j.cell.2008.07.041', 'https://doi.org/10.1089/scd.2013.0157', 'https://doi.org/10.1002/hep.', 'https://doi.org/', 'https://doi.org/10.1093/toxsci/kft176', 'https://doi.org/10.1038/srep35434', 'https://doi.org/10.1002/hep.26160', 'https://doi.org/10.', 'https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1016/j.cell.2018.11.013', 'https://doi.org/', 'https://doi.org/10.1159/000335753', 'https://doi.org/10.1016/j.stem.2012.10.010', 'https://doi.org/10.1161/CIRCULATIONAHA.', 'https://doi.org/10.1038/nature09747', 'https://doi.org/10.1038/nature09855', 'https://doi.org/10.1161/01.CIR.102.6.706', 'https://doi.org/10.1038/bjp.2008.191', 'https://doi.org/10.1111/j.1476-5381.2009.00191.x', 'https://doi.org/10.1093/cvr/28.6.923', 'https://doi.org/10.', 'https://doi.org/10.1016/j.taap.2012.09.', 'https://doi.org/10.1111/jcmm.13702', 'https://doi.org/10.2174/138161211796904812', 'https://doi.org/10.1038/nm.4087', 'https://doi.org/10.1016/j.taap.2013.', 'https://doi.org/10.1016/j.tox.2014.', 'https://doi.org/10.1007/s12265-012-9396-1', 'https://doi.org/10.1093/toxsci/', 'https://doi.org/10.1007/s12015-010-9113-x', 'https://doi.org/10.1111/j.1476-5381.2011.01558.x', 'https://doi.org/10.1038/nature06196', 'https://doi.org/10.1038/ncomms1260', 'https://doi.org/10.', 'https://doi.org/10.1042/BCJ20170780', 'https://doi.org/10.1016/j.stemcr.2017.07.024', 'https://doi.org/10.3791/52483', 'https://doi.org/10.1016/j.ctrv.2004.05.002', 'https://doi.org/10.1007/s00216-008-2291-6', 'https://doi.org/10.1124/dmd.117.075945', 'https://doi.org/10.1177/1535370214529398', 'https://doi.org/10.1126/scitranslmed.aad8278', 'https://doi.org/10.1016/j.stem.2013.11.002', 'https://doi.org/10.1016/S0140-6736(13)60844-2', 'https://doi.org/10.1038/nrgastro.2015.111', 'https://doi.org/10.1128/mBio.00159-12', 'https://doi.org/10.1016/j.cell.2015.03.053', 'https://doi.org/10.1186/s13059-014-0428-9', 'https://doi.org/10.7554/eLife.18489', 'https://doi.org/10.1002/jps.', 'https://doi.org/10.1101/cshperspect.a014027', 'https://doi.org/10.1093/cvr/cvs206', 'https://doi.org/10.1093/eurheartj/eht067', 'https://doi.org/10.1093/eurheartj/ehr073', 'https://doi.org/10.1242/dmm.008409', 'https://doi.org/10.1093/eurheartj/ehs226', 'https://doi.org/10.1161/CIRCGENETICS.113.000188']
# ['https://doi.org/10.1155/2017/7156489', 'https://www.hindawi.com']
# ['https:// creativecommons .org/ licenses/ by -nc -sa/ 4 .0/ ).', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https:// doi .org/ 10 .1083/ jcb .201301090', 'https:// doi ', 'https:// doi .org/ 10 .1016/ j .cub .2004 .09 .022', 'https:// doi .org/ 10 .1038/ 35099020', 'https:// doi .org/ 10 .1083/ jcb .201008108', 'https:// doi .org/ 10 .1016/ ', 'https:// doi .org/ ', 'https:// doi ', 'https:// doi .org/ 10 .1128/ MCB ', 'https:// doi .org/ 10 .1126/ science .1176495', 'https:// doi .org/ 10 .1016/ ', 'https:// doi .org/ 10 .1016/ S0378 ', 'https:// doi .org/ 10 .1099/ 00221287 ', 'https:// doi .org/ 10 .1091/ mbc .e11 -05 -0434', 'https:// doi .org/ 10 .1016/ S0092 -8674(01)00596 ', 'https:// doi .org/ 10 .1083/ jcb ', 'https:// doi .org/ 10 .1126/ science ', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 .1242/ jcs .109157', 'https:// doi .org/ 10 .1101/ gad .6 .1 .93', 'https:// doi .org/ 10 .1111/ j .1742 -4658 ', 'https:// doi .org/ 10 .1091/ mbc .e06 -09 -0822', 'https:// doi ', 'https:// doi .org/ 10 .1101/ cshperspect .a022343', 'https:// doi ', 'https:// doi .org/ 10 .1016/ j .semcdb .2015 .12 .012', 'https:// doi .org/ 10 .1146/ annurev -cellbio ', 'https:// doi .org/ 10 .1016/ j .cell .2005 .07 ', 'https:// doi ', 'https:// doi .org/ 10 .1016/ 0014 -4827(71)90223 -0', 'https://doi.org/10.1083/jcb.201805100', 'https://doi.org/10.1083/jcb.201805100', 'https:// doi .org/ 10 .1126/ ', 'https:// doi .org/ 10 .1091/ mbc .e04 -12 -1114', 'https:// doi .org/ 10 .1038/ nature02026', 'https:// doi .org/ 10 .1038/ ', 'https:// doi .org/ 10 .1016/ j .gene ', 'https:// doi .org/ 10 .1083/ jcb .200604107', 'https:// doi .org/ 10 .1016/ j .cub .2009 .10 ', 'https:// ', 'https:// doi .org/ 10 .1186/ jbiol195', 'https:// doi .org/ 10 .1038/ nsmb .2706', 'https:// doi .org/ 10 .1016/ j .cell .2012 .05 ', 'https:// doi .org/ 10 .15252/ embj .201488958', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 .1091/ mbc ', 'https:// doi .org/ 10 .1242/ jcs .206334', 'https:// doi .org/ 10 .1128/ MMBR ', 'https:// doi .org/ 10 .1128/ MMBR .69 ', 'https:// doi .org/ 10 .1016/ 0092 -8674(81)90015 -5', 'https:// doi .org/ 10 .1002/ (SICI)1097 ', 'https:// doi .org/ 10 .1016/ j .cub .2013 .07 .032', 'https:// doi ', 'https:// doi .org/ 10 .1091/ mbc .e17 -06 -0404', 'https:// doi .org/ 10 ', 'https:// doi .org/ 10 .1016/ S0962 -8924(00)01901 -2', 'https:// doi .org/ 10 .1242/ jcs .063891', 'https:// doi .org/ 10 .4161/ cc .11 .2 .18857', 'https:// ', 'https:// doi .org/ 10 .1038/ ncb1855', 'https:// doi .org/ 10 ', 'https:// doi ', 'https:// doi .org/ 10 ', 'https:// ', 'https://  ...
# ['https://doi.org/10.1016/j.molcel.2018.03.016', 'https://doi.org/10.1016/j.molcel.2018.03.016', 'https://doi.org/10.1016/j.molcel.', 'https://data.mendeley.com/datasets/', 'https://imagej.nih.gov/ij', 'https://pymol.org/2/', 'https://www.microsoft.com/store/b/home', 'https://systatsoftware.com/products/']
# ['https://doi.org/10.1007/s10750-017-3423-9', 'https://doi.org/10.1007/s10750-017-3423-9) con-', 'https://doi.org/', 'https://www-01.ibm.com/common/ssi/']
# ['https://www.kyazma.nl/index.']
# ['https://doi.org/10.1155/2018/8510620', 'https://www.brown.edu/research/labs/wessel/wally-']
# ['https://cran.r-project.']
# ['https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:35:42, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231200002X']
# ['https://doi.org/10.1155/2018/7382351', 'https://sciex.com/software-downloads-x2110). The']
# ['https://doi.org/10.1016/j.clinbiochem.2019.07.007', 'https://www.who.int/biologicals/BS.2018.2339_Free_PSA.pdf.', 'https://www.who.int/biologicals/BS.2018.2340_']
# ['https://www.nbstrn.org/supported-', 'https://www.team-share.net/NDSI-IEM-Initiative/Overview.aspx.']
# ['https://zhanglab.ccmb.med.umich.edu/GPCR-EXP/. ']
# ['https://doi.org/10.1016/j.clinbiochem.2018.10.011']
# ['https://doi.org/10.1007/s10750-017-3364-3', 'https://CRAN.R-project.org/package=maptools.', 'https://', 'https://www.R-project.org/.']
# ['https://dx.doi.org/10.6084/m9.']
# ['https://doi.org/10.1007/s10750-018-3572-5', 'https://doi.org/10.1007/s10750-018-3572-5) con-', 'https://cran.r-project.']
# ['https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:37:04, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672311000097']
# ['https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1016/j.tibs.2008.06.002', 'https://doi.org/10.4161/cl.21912', 'https://doi.org/10.4161/cl.21882', 'https://doi.org/10.4161/sgtp.', 'https://doi.org/10.1007/s12640-016-9613-9', 'https://doi.org/10.1073/pnas.0705003104', 'https://doi.org/10.1021/acs.jmedchem.', 'https://doi.org/10.1016/j.cellsig.2008.11.001', 'https://doi.org/10.4161/cl.21602', 'https://doi.org/10.', 'https://doi.org/10.1186/s13041-016-0230-6', 'https://doi.org/10.1038/1675', 'https://doi.org/10.1016/j.ejmg.2017.01.004', 'https://doi.org/10.1161/CIRCULATIONAHA.111.048785', 'https://doi.org/10.1111/bph.13872', 'https://doi.org/10.1016/j.yjmcc.2011.09.016', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1016/j.yjmcc.2009.', 'https://doi.org/10.1152/ajpheart.00612.2011', 'https://doi.org/10.1016/j.cellsig.2014.04.020', 'https://doi.org/10.1128/MCB.21.15.5179-5189.2001', 'https://doi.org/10.1016/S0092-8674(00)00043-X', 'https://doi.org/10.1038/embor.2012.75', 'https://doi.org/10.1016/j.jmb.2006.06.017', 'https://doi.org/10.1074/', 'https://doi.org/10.1074/jbc.M110.156505', 'https://doi.org/10.1073/pnas.1214447109', 'https://doi.org/10.1073/pnas.1717437115', 'https://doi.org/10.1016/j.str.2007.01.001', 'https://doi.org/10.1371/journal.pone.0077818', 'https://doi.org/10.1016/j.bmcl.2016.04.037', 'https://doi.org/10.1016/j.', 'https://doi.org/10.1016/j.bbapap.2017.10.004', 'https://doi.org/10.1038/ncomms9681', 'https://doi.org/10.1016/j.str.2011.10.013', 'https://doi.org/10.1002/anie.201108865', 'https://doi.org/10.1021/acsmedchemlett.5b00102', 'https://doi.org/10.1021/acsmedchemlett.6b00322', 'https://doi.org/10.1021/acsmedchemlett.', 'https://doi.org/10.1021/ja805555a', 'https://doi.org/10.1016/j.bcp.2010.03.012', 'https://doi.org/10.', 'https://doi.org/10.1016/j.jmb.2006.02.027', 'https://doi.org/10.1038/nature09593', 'https://doi.org/10.1016/j.jsb.2010.06.008', 'https://doi.org/10.1007/s12575-009-9008-x', 'https://doi.org/10.1016/S0006-3495(00)76713-0', 'https://doi.org/10.1042/BCJ20180867', 'https://doi.org/10.1016/S0003-2697(03)00289-6', 'https://doi.org/10.1107/S0021889810008289', 'https://doi.', 'https://doi.org/10.1007/', 'https://doi.org/10.1002/prot.22588', 'https://doi.org/10.1093/nar/gkw389', 'https://doi.org/10.1107/S1399004715002576', 'https://doi.org/10.1016/S0006-3495(01)76260-1', 'https://doi.org/', 'https://doi.org/10.1107/', 'https://doi.org/10.1107/S0021889807021206', 'https://doi.org/10.1107/S0907444909052925', 'https://doi.org/10.1107/S0907444909042073', 'https://doi.org/10.1016/S1097-2765(01)00428-2', 'https://doi.org/10.1002/bms.1200220902', 'https://doi.org/10.1002/oms.1210270709', 'https://doi.org/10.1002/ajmg.a.20131', 'https://doi.org/10.1093/hmg/', 'https://doi.org/10.1002/ajmg.a.31956', 'https://doi.org/10.1038/mp.2014.189', 'https://doi.org/10.1080/10826076.2012.743724', 'https://doi.org/10.1016/j.ymeth.2008.10.020', 'https://doi.org/10.1016/S0165-022X(03)00053-8', 'https://doi.org/10.1007/978-981-10-6038-0_3']
# ['https://github.com/cgevans/', 'https://books.google.com/books?id=sk3OBQAAQBAJ&pgis=1', 'https://books.google.com/books?hl=en&lr=&id=n7lLTzD6PHYC&pgis=1', 'https://www.researchgate.net/profile/John_Conery/', 'https://doi.', 'https://doi.org/10.1021/es049822c']
# ['https://', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:31:34, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000016', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:31:34, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000016', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:31:34, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000016', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:31:34, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000016', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:31:34, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000016']
# ['https://doi.org/10.1155/2018/3868070']
# ['https://doi.org/10.1017/', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:21:52, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000065', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:21:52, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000065', 'https://pymol.org/2/; Schrödinger, LLC).', 'https://github.', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:21:52, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000065', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:21:52, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000065', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:21:52, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000065', 'https://orcid.org/0000-0002-6803-4456', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:21:52, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000065', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:21:52, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672319000065']
# ['https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/', 'https://github.com/', 'https://', 'https://doi.', 'https://doi.org/', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio', 'https://doi.org/10.1038/s42003-019-0555-7', 'https://doi.org/', 'https://doi.org/10.5281/', 'https://doi.org/10.1038/s42003-', 'https://doi.org/10.1038/s42003-019-0555-7 | www.nature.com/commsbio']
# ['https://doi.org/10.1016/j.molcel.2017.10.030']
# ['https://doi.org/10.1016/j.molcel.2017.10.022', 'https://doi.org/10.1016/j.molcel.2017.10.022', 'https://doi.org/10.1016/j.molcel.2017.10.022.', 'https://www.zeiss.com/', 'https://imagej.nih.gov/ij/']
# ['https://doi.org/10.1007/s10750-017-3441-7', 'https://', 'https://']
# ['https://cran.r-pro-', 'https://cran.r-project.org/web/packages/mcr/index.html2014.']
# ['https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:34:21, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672314000226']
# ['https://doi.org/10.1007/s10750-018-3840-4 (0123456789().,-volV)(0123456789().,-volV)', 'https://waterdata.usgs.gov/nwis/']
# ['https://doi.org/10.1016/j.clinbiochem.2017.10.013', 'https://www.cadth.ca/protein-testing-patients-multiple-myeloma-review-clinical-']
# ['https://doi.org/10.1186/s12863-018-0709-5', 'https://github.com/cbkmephisto/SNPipeline) and FIm-', 'https://github.com/', 'https://ucanr.edu/sites/UCCE_LR/files/152458.pdf.', 'https://www.aphis.usda.gov/']
# ['https://doi.org/10.1038/s41598-019-48335-6', 'https://doi.org/10.1038/s41598-019-48335-6', 'https://doi.org/10.1038/s41598-019-48335-6', 'https://doi.org/10.1038/s41598-019-48335-6', 'https://doi.org/10.1038/s41598-019-48335-6', 'https://doi.org/10.1038/s41598-019-48335-6', 'https://doi.org/10.1038/s41598-019-48335-6']
# ['https://doi.org/10.1038/s41467-019-11790-w', 'https://doi.org/10.1038/s41467-019-11790-w | www.nature.com/naturecommunications', 'https://doi.org/10.1038/s41467-019-11790-w', 'https://doi.org/10.1038/s41467-019-11790-w | www.nature.com/naturecommunications', 'https://doi.org/10.1038/s41467-019-11790-w', 'https://doi.org/10.1038/s41467-019-11790-w | www.nature.com/naturecommunications', 'https://doi.org/10.1038/s41467-019-11790-w', 'https://doi.org/10.1038/s41467-019-11790-w | www.nature.com/naturecommunications', 'https://doi.org/10.1038/s41467-019-11790-w', 'https://doi.org/10.1038/s41467-019-11790-w | www.nature.com/naturecommunications', 'https://doi.org/10.1038/s41467-019-11790-w', 'https://doi.org/10.1038/s41467-019-11790-w | www.nature.com/naturecommunications', 'https://doi.org/10.1038/s41467-019-11790-w', 'https://doi.org/10.1038/s41467-019-11790-w | www.nature.com/naturecommunications', 'https://doi.org/10.1038/s41467-019-11790-w', 'https://www.who.int/malaria/publications/', 'https://doi.org/10.1038/s41467-019-11790-w | www.nature.com/naturecommunications', 'https://doi.org/10.1038/s41467-019-11790-w', 'https://doi.org/10.1101/251082 (2018).', 'https://doi.org/10.1111/', 'https://doi.org/10.1038/s41467-', 'https://doi.org/10.1038/s41467-019-11790-w | www.nature.com/naturecommunications']
# ['https://doi.org/10.1007/s10750-018-3750-5 (0123456789().,-volV)(0123456789().,-volV)', 'https://doi.org/10.1007/s10750-018-3750-5) con-', 'https://doi.org/10.1111/', 'https://doi.org/10.1101/278309.', 'https://www.woking.gov.uk/environment/greeninf/']
# ['https://doi.org/10.1007/s10750-018-3644-6', 'https://doi.org/']
# ['https://doi.org/10.1186/s12863-019-0750-z', 'https://scholar.google.com).']
# ['https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6', 'https://doi.org/10.1038/s41598-019-48181-6.', 'https://doi.org/10.1038/s41598-019-48181-6']
# ['https://doi.org/10.1038/s41597-019-0053-2', 'https://doi.org/10.1038/s41597-019-0053-2', 'https://doi.org/10.1038/s41597-019-0053-2', 'https://ecvam-dbalm.', 'https://doi.org/10.1038/s41597-019-0053-2', 'https://doi.org/10.1038/s41597-019-0053-2', 'https://doi.org/10.1038/s41597-019-0053-2', 'https://doi.org/10.1038/s41597-019-0053-2', 'https://doi.org/10.1038/s41597-019-0053-2', 'https://doi.org/10.1080/02652030701744538 (2008).', 'https://doi.org/10.3109/17435390.2', 'https://doi.org/10.1289/ehp.7339 (2005).', 'https://doi.org/10.1080/02652030802007553 (2008).', 'https://doi.org/10.1002/wnan.153 (2011).', 'https://doi.org/10.1111/joim.12109 (2013).', 'https://ssl.biomax.de/nanomile/cgi/login_bioxm_portal.cgi (2018).', 'https://cordis.europa.eu/project/rcn/106943/reporting/en (2017).', 'https://doi.org/10.1124/dmd.107.020016 (2008).', 'https://doi.org/10.3390/microarrays5020008 (2016).', 'https://doi.org/10.1016/j.nano.2013.04.010 ', 'https://doi.org/10.1371/journal.', 'https://doi.org/10.1038/s41597-019-0053-2', 'https://doi.org/10.1021/acsami.5b11216 (2016).', 'https://ec.europa.eu/jrc/en/scientific-tool/jrc-', 'https://doi.org/10.1007/s00204-017-2106-7 (2017).', 'https://doi.org/10.2905/', 'https://doi.org/10.1073/pnas.0604348103 (2006).', 'https://doi.org/10.1088/1749-4699/6/1/014006 (2013).', 'https://doi.org/10.1177/108705719900400206 (1999).', 'https://doi.org/10.6084/m9.figshare.c.4434041 (2019).', 'https://doi.org/10.1038/s41597-019-0053-2']
# ['https://creativecommons.org/licenses/by/4.0), which permits unrestricted use,']
# ['https://doi.org/10.1186/s12863-018-0685-9', 'https://doi.org/', 'https://serval.unil.ch/notice/serval:BIB_DB589E420FA0 (2018).']
# ['https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:26:36, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672313000220', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:26:36, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672313000220', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:26:36, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672313000220', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:26:36, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672313000220', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:26:36, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672313000220', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:26:36, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672313000220', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:26:36, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672313000220', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:26:36, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672313000220', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:26:36, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672313000220']
# ['https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).', 'https://doi.org/10.1083/jcb.201612106']
# ['https://doi.org/10.1007/s10750-018-3863-x (0123456789().,-volV)(0123456789().,-volV)']
# ['https://doi.org/10.1007/s10750-018-3816-4 (0123456789().,-volV)(0123456789().,-volV)', 'https://doi.org/10.1007/s10750-018-3816-4) con-']
# ...
# ['https://doi.org/10.1007/s10750-018-3776-8 (0123456789().,-volV)(0123456789().,-volV)', 'https://generalhydroponics.com/', 'https://www.ebi.ac.uk/Tools/msa/clustalo/).', 'https://', 'https://doi.org/10.']
# ['https://dx.doi.org/10.6084/m9.']
# ['https://www.fda.gov/newsevents/newsroom/pressannouncements/ucm587547.htm. ', 'https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K123486. ', 'https://www.spritam.com/#/hcp/zipdose-technology/what-is-zipdose-technology. ', 'https://futurism.com/3d-printed-tritanium-spinal-implant-simulates-actual-bone. ', 'https://www.stratasys.com/materials/search. ', 'https://www.ethicon.com/emea/products/wound-closure/absorbable-sutures/monocryl-', 'https://www.crbard.com/Davol/en-', 'https://www.spineology.com/united-', 'https://www.accessdata.fda.gov/cdrh_docs/pdf16/K163673.pdf. ', 'https://www.carbon3d.com/industry/dental-', 'https://formlabs.com/materials/dental/. ', 'https://envisiontec.com/wp-', 'https://formlabs.com/industries/dental/ https://formlabs.com/materials/dental/. ', 'https://3dprint.nih.gov/collections/prosthetics. ', 'https://3dprintingindustry.com/news/materialise-partners-with-university-of-', 'https://ois.net/jjs-plans-', 'https://www.accessdata.fda.gov/drugsatfda_docs/nda/2015/207958Orig1s000TOC.cfm. ', 'https://www.spritam.com/#/patient/about-']
# ['https:// doi .org/ 10 .1083/ jcb .201805003) explore the three-dimensional architecture of vertebrate neocentromeres, leading to a model ', 'https:// creativecommons .org/ licenses/ by -nc -sa/ 4 .0/ ).', 'https://doi.org/10.1083/jcb.201811172', 'https://doi.org/10.1083/jcb.201811172', 'https:// doi .org/ 10 ', 'https://doi.org/10.1083/jcb.201811172', 'https://doi.org/10.1023/jcb.201811172J. Cell Biol. 2019 Vol. 218 No. 2\u2003722Rockefeller University Press\x0c']
# ['https://doi.org/10.1083/jcb.201705070', 'https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).']
# ['https://doi.org/10.1155/2017/4701481', 'https://www.hindawi.com']
# ['https://doi.org/10.1155/2018/4963942', 'https://doi.org/10.1016/j.atherosclerosissup']
# ['https://dx.doi.org/10.6084/m9.']
# ['https://cran.r-project.org/package=']
# ['https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).', 'https://doi.org/10.1083/jcb.201702177']
# ['https://familyhistory.hhs.gov']
# ['https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).', 'https://doi.org/10.1083/jcb.201612068']
# ['https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).', 'https://doi.org/10.1083/jcb.201702177']
# ['https://doi.org/10.1016/j.molcel.2018.04.022', 'https://doi.org/10.1016/j.molcel.2018.04.022', 'https://doi.org/10.1016/j.molcel.2018.04.022.', 'https://imagej.nih.gov/ij/']
# ['https://public-registry.jbei.org/ ', 'https://www.denovodna.com/software/ ', 'https://j5.jbei.org ', 'https://chopchop.rc.fas.harvard.edu/ ', 'https://synbiotools.bbn.com/ ']
# ['https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099', 'https://www.google.com/url?', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:36:16, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S0016672315000099']
# ['https://doi.org/10.1007/s10750-018-3647-3']
# ['https://doi.org/10.1083/jcb.201704048', 'https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).', 'https ://doi .org /10 .1074 /jbc ', 'https ://doi .org /10 ', 'https ://doi .org /10 .1016 /j .ejcb ', 'https ://doi .org /10 .1186 /bcr1329', 'https ://doi .org /10 .1016 /j .ejcb .2014 .07 .003', 'https ://doi .org /10 .1016 /S0076 -6879(02)45028 -8', 'https ://doi .org /10 .4161 /cam .28349', 'https ://doi .org /10 .1016 /j .ejcb .2005 .09 .018', 'https ://doi ', 'https ://doi .org /10 .1038 /sj .emboj ', 'https ://doi .org /10 ', 'https ://doi .org /10 .1242 /jcs .123547', 'https ://doi .org /10 .1007 /s10555 -008 ', 'https ://doi .org /10 .1146 /annurev -cellbio -111315 -125227', 'https ://doi .org /10 .1038 /', 'https ://doi .org /10 .1002 /jez .1402510206', 'https ://doi .org /10 .1111 /j .1749 -6632 .1999 .tb07695 .x', 'https ://doi .org /10 .1158 /0008 -5472 .CAN -06 -3928', 'https ://doi .org /10 .1146 /annurev .cellbio .21 .122303 ', 'https ://doi .org /10 .1096 ', 'https ://doi .org /10 ', 'https ://doi .org /10 .1074 /jbc ', 'https ://doi .org /10 .1016 /j .ceb .2011 .04 .002', 'https ://doi .org /10 .1016 /j .tcb .2017 .03 .003', 'https ://doi .org /10 .1007 /978 -1 -4899 -4541 -9', 'https ://doi .org ', 'https ://doi .org /10 ', 'https ://doi .org /10 .1021 /bi400678y', 'https ://doi .org /10 .1083 /jcb .201403127', 'https ://doi .org /10 .1186 /1471 -2407 -13 -63', 'https ://doi .org /10 .1016 /j .ceb .2008 .01 .005', 'https ://doi .org /10 .1242 /jcs .092726', 'https ', 'https ://doi .org /10 .1074 /jbc .M105363200', 'https ://doi .org /10 .1083 ', 'https ://doi .org /10 .1242 /jcs .03364', 'https ', 'https ://doi .org /10 .1042 /BST0330891', 'https ://', 'https ://doi .org /10 ', 'https ://doi .org /10 .1016 /S0091 -679X(08)85004 -2', 'https ://doi .org ', 'https ://doi .org /10 .1083 /', 'https ://doi .org /10 .1091 /mbc ', 'https ', 'https ://doi .org /10 .4161 /cam .28406', 'https ://doi ', 'https ://doi .org /10 .1158 /0008 ', 'https ://doi .org /10 .1083 /jcb .201103045', 'https ://doi .org ', 'https ://doi .org /10 .1021 /pr060140t', 'https ://doi .org /10 .4049 /jimmunol .1501655', 'https ://doi .org ', 'https ://doi .org /10 ', 'https ://doi .org /10 .1038 /ncb2972', 'https ://doi .org /10 .1002 /ijc .2910280612', 'https ', 'https ://doi .org /10 .1016 /j .bpj .2010 .12 .3733', 'https ://doi ', 'https ://doi .org /10 .1038 /nature04665', 'https ://doi .org /10 .1038 /srep25502', 'https ://doi .org /10 .1038 /onc .2013 .377', 'https ://doi .org /10 .1091 /mbc .E16 -12 -0885', 'https ://doi .org ', 'https ://doi .org /10 .1083 ', 'https ://', 'https ://doi ', 'https ://doi .org /10 .1126 /science .1247005', 'https ://doi .org /10 .1038 /ncomms12405', 'https ://doi ', 'https ://doi .org ', 'https ://doi .org /10 .1016 /B978 -0 ', 'https ', 'https ://doi .org /10 .1093 /cercor /bhs402', 'https ://doi .org /10 .1074 /jbc ', 'https ://doi .org /10 .1074 /jbc .275 .18 .13901', 'https ://doi .org /10 .1186 /1472 -6750 -3 -13', 'https ://doi .org /10 .1016 /0092 ', 'https ://doi .org /10 ', 'https ://doi .org /10 ', 'https ://doi .org /10 .1016 /j .ceb .2005 .08 ', 'https ://doi .org /10 .1083 ', 'https ://doi .org /10 .1074 /jbc .M807845200', 'https ://doi .org /10 .1038 /onc .2013 .363', 'https ://doi .org /10 .1074 /jbc ']
# ['https://doi.org/10.1017/S001667231900003X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:25:05, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231900003X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:25:05, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231900003X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:25:05, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231900003X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:25:05, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231900003X', 'https://www.cambridge.org/core. IP address: 213.79.89.166, on 16 Aug 2019 at 09:25:05, subject to the Cambridge Core terms of use, available at', 'https://www.cambridge.org/core/terms. https://doi.org/10.1017/S001667231900003X']
# ['https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8', 'https://doi.org/10.1038/s41598-019-47337-8']
# ['https://doi.org/10.1007/s10750-019-3956-1 (0123456789().,-volV)(0123456789().,-volV)', 'https://doi.org/10.1007/s10750-019-3956-1) con-', 'https://cran.r-project.org/web/packages/vegan/index.html.', 'https://doi.org/10.1017/s0022149x18000482.']
# ['https://github.com/harmslab/wheeler-harms-S100A5-Ca-Cu-', 'https://academic.oup.com/chemse/article/39/5/', 'https://github.com/harmslab/pytc.', 'https://', 'https://link.springer.com/article/10.']
# ['https://www.cabi.org/', 'https://doi.org/10.', 'https://doi.org/10.1186/s13007-018-0323-6.', 'https://doi.org/10.', 'https://www.engineeringtoolbox.com/maxi']
# ['https://doi.org/10.1155/2019/4625279']
# ['https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1016/j.plantsci.2012.04.013', 'https://doi.org/10.1074/jbc.R700029200', 'https://doi.org/10.1002/bip.21256', 'https://doi.org/10.12688/f1000research.8133.1', 'https://doi.org/10.1023/A:1012440926982', 'https://doi.org/10.1104/pp.115.3.1259', 'https://doi.org/10.1074/jbc.272.27.16746', 'https://doi.org/10.1073/pnas.94.22.12230', 'https://doi.org/10.1016/S1360-1385', 'https://doi.org/10.1105/tpc.104.025379', 'https://doi.org/10.1021/bi300570v', 'https://doi.org/10.1021/bi2004312', 'https://doi.org/10.1021/bi201425f', 'https://doi.org/10.1371/journal.pone.0002039', 'https://doi.org/10.1371/', 'https://doi.org/10.1016/j.plantsci.2016.03.013', 'https://doi.org/10.1007/s00425-003-1192-3', 'https://doi.org/10.1093/pcp/pcu027', 'https://doi.org/10.1007/s12355-010-0041-5', 'https://doi.org/10.4172/2155-9600.1000497', 'https://doi.org/10.1093/aob/', 'https://doi.org/10.1093/', 'https://doi.org/10.', 'https://doi.org/10.1042/BCJ20190154', 'https://doi.org/10.1002/(SICI)1097-0231(19990315)13:5<315::AID-RCM483>3.0.CO;2-C', 'https://doi.org/10.1172/JCI24650', 'https://doi.org/10.1016/S0969-2126(00)00194-5', 'https://doi.org/10.1016/j.bbapap.2013.02.024', 'https://doi.org/10.1021/bi051902l', 'https://doi.org/10.', 'https://doi.org/10.1021/bi0100790', 'https://doi.org/10.3390/ijms17050640', 'https://doi.org/10.1074/jbc.M110.159541', 'https://doi.org/10.1007/BF00197106', 'https://academicpublishingplatforms.com/journal.php?journal=PARB', 'https://doi.org/10.1073/pnas.0800585105', 'https://doi.org/10.1016/j.niox.2014.04.003', 'https://doi.org/10.1104/pp.106.086918', 'https://doi.org/10.1007/PL00008128', 'https://doi.org/10.1086/336870', 'https://www.seedtest.org/en/content—1–1084.html', 'https://doi.org/10.1093/jxb/', 'https://doi.org/10.1007/s11738-017-2569-4', 'https://doi.org/10.1111/j.1469-8137.2007.02226.x', 'https://doi.org/10.1529/biophysj.105.060582', 'https://doi.org/10.1111/tpj.12340', 'https://doi.org/10.3389/fpls.', 'https://doi.org/10.1016/j.jmb.2007.05.029', 'https://doi.org/10.1021/bi060716s', 'https://doi.org/10.1021/ja066638d']
# ['https://doi.org/10.1016/j.molcel.2017.10.033', 'https://doi.org/10.1016/j.molcel.2017.10.033', 'https://doi.org/10.1016/j.molcel.2017.10.033.', 'https://doi.org/10.17632/xgbjnmxnbr.1', 'https://doi.org/10.17632/']
# ['https://doi.org/10.1016/j.molcel.2017.12.019', 'https://doi.org/10.1016/j.molcel.2017.12.019', 'https://doi.org/10.17632/k2t8nx8kh5.1', 'https://doi.org/10.17632/k2t8nx8kh5.1', 'https://portal.thermo-brims.com/', 'https://www.rstudio.com/', 'https://www.graphpad.com', 'https://doi.org/10.17632/k2t8nx8kh5.1).']
# ['https://doi.org/10.1038/s41398-019-0539-x', 'https://breenms.shinyapps.io/DEXPTSD/.', 'https://doi.org/']
# ['https ://creativecommons .org /licenses /by -nc -sa /4 .0 /).', 'https://doi.org/10.1083/jcb.201612169']
# ['https://www.intechopen.com/books/next-generation-sequencing-advances-applications-and-challeng']
# ['https://doi.org/10.1186/s12863-019-0722-3', 'https://doi.', 'https://doi.org/10.1186/1297-9686-46-34.']
# ['https://doi.org/10.1016/j.clinbiochem.2019.06.001', 'https://www.']
# ['https://www.avacta.com).']
# ['https://doi.org/10.1016/j.molcel.2017.11.028']
# ['https://doi.org/10.1007/s10750-018-3864-9 (0123456789().,-volV)(0123456789().,-volV)', 'https://nrfa.ceh.ac.uk/', 'https://vemco.com/wp-']
# ['https://www.asminternational.org/documents/10192/1849770/06974G_Chapter_1.pdf ', 'https://grabcad.com/library/femur-bone-2. ', 'https://forum.solidworks.com/thread/189281. ', 'https://www.healthpages.org/anatomy-', 'https://healthfully.com/do-ligaments-do-skeletal-system-']
# ['https://imagej.nih.gov/ij/', 'https://www.ﬂowjo.com/', 'https://github.com/BradnerLab/pipeline/', 'https://github.com/BradnerLab/pipeline/', 'https://pypi.python.org/pypi/coltron', 'https://github.com/BradnerLab/netseq', 'https://github.com/BradnerLab/pipeline/wiki/bamliquidator). Brieﬂy, ChIP-Seq reads aligning to the region were', 'https://github.com/BradnerLab/pipeline/ (ROSE2_main.py). Default parameters, including exclusion of', 'https://github.com/BradnerLab/netseq. Brieﬂy, the six 50 end nucleotides of the', 'https://', 'https://github.com/BradnerLab/', 'https://pypi.python.org/pypi/coltron.']
# ['https://doi.org/10.1016/j.clinbiochem.2018.01.020', 'https://']

# %%
# re.findall(r'.[A-Z]+[a-z]+', bio["text"].iloc[0])
# # [A-Z]+[a-z]+ -- ищем подстроку вида "{какое-то кол-во заглавных букв}{какое-то кол-во строчных букв}"
# # .[A-Z]+[a-z]+ -- ищем подстроку вида "{любой символ кроме начала строки}{какое-то кол-во заглавных букв}{какое-то кол-во строчных букв}"
# Out:
# [' Do',
#  ' Health',
#  ' Research',
#  ' Centre',
#  ' Department',
#  ' Pharmacology',
#  ' Lung',
#  ' Health',
#  ' Research',
#  ' Centre',
#  ' University',
#  ' Melbourne',
#  ' Victoria',
#  ' Australia',
#  ' In',
#  ' We',
#  ' The',
#  '‘Omnis',
#  ' Virchow',
#  ' Bertoncello',
#  ' Lung',
#  ' Health',
#  ' Research',
#  ' Department',
#  ' Pharmacology',
#  ' Lung',
#  ' Health',
#  ' Research',
#  ' Level',
#  ' Medical',
#  ' Building',
#  ' The',
#  ' University',
#  ' Melbourne',
#  ' Australia',
#  ' Email',
#  ' Authors',
#  ' Associate',
#  ' Professor',
#  ' Ivan',
#  ' Bertoncello',
#  ' Lung',
#  ' Regeneration',
#  ' Laboratory',
#  ' Dr',
#  ' Mc',
#  ' Lung',
#  ' Stem',
#  ' Cells',
#  ' Microenvi',
#  ' Group',
#  ' January',
#  ' January',
#  ' February',
#  ' February',
#  ' The',
#  ' Authors',
#  ' Asian',
#  ' Paci',
#  ' Society',
#  ' Respirology',
#  ' Rare',
#  ' Relatively',
#  ' This',
#  ' In',
#  ' The',
#  ' Multipotent',
#  ' Bertoncello',
#  ' Mc',
#  '(Omnis',
#  ' The',
#  ' The',
#  ' Airway',
#  ' However',
#  ' Accordingly',
#  '(Fig',
#  ' As',
#  ' Day',
#  ' In',
#  ' Day',
#  ' The',
#  ' Authors',
#  ' Asian',
#  ' Paci',
#  ' Society',
#  ' Respirology',
#  '\x0cEpithelial',
#  ' Analysis',
#  ' Regional',
#  ' There',
#  ' Subpopulations',
#  ' Till',
#  ' Like',
#  ' Lajtha',
#  ' He',
#  ' In',
#  ' The',
#  ' Authors',
#  ' Asian',
#  ' Paci',
#  ' Society',
#  ' Respirology',
#  ' Scho',
#  ' He',
#  ' The',
#  ' In',
#  ' For',
#  ' Speci',
#  ' Robust',
#  ' Transplant',
#  ' Lineage',
#  ' Genetically',
#  '(Fig',
#  ' The',
#  ' However',
#  ' Bertoncello',
#  ' Mc',
#  ' Stem',
#  ' The',
#  ' Discord',
#  ' Transplant',
#  ' Evidence',
#  ' The',
#  ' While',
#  ' The',
#  ' Distal',
#  ' The',
#  ' Authors',
#  ' Asian',
#  ' Paci',
#  ' Society',
#  ' Respirology',
#  '\x0cEpithelial',
#  ' Regenerative',
#  '(Clara',
#  ' Brie',
#  '(Fig',
#  ' These',
#  '(Krt',
#  ' The',
#  ' Authors',
#  ' Asian',
#  ' Paci',
#  ' Society',
#  ' Respirology',
#  '(CCSPpos',
#  '(Scgb',
#  '(Clara',
#  ' Krt',
#  ' Cy',
#  ' Scgb',
#  ' Scgb',
#  '(Clara',
#  '(Clara',
#  '-Cpos',
#  ' However',
#  ' Bertoncello',
#  ' Mc',
#  ' On',
#  ' In',
#  ' Krt',
#  ' Likewise',
#  '(NGFRposa',
#  ' In',
#  '(Clara',
#  '(Clara',
#  ' Other',
#  ' Scgb',
#  'sKrt',
#  'sKrt',
#  ' In',
#  '-Cneg',
#  '(CGRPpos',
#  '(Fig',
#  ' However',
#  ' In',
#  ' This',
#  ' These',
#  ' Bertoncello',
#  'cQualter',
#  ' More',
#  ' Multiparameter',
#  ' NGFRposa',
#  ' Krt',
#  ' Krt',
#  ' Krt',
#  ' Oeztuerk',
#  '-Winder',
#  '-Cadpos',
#  ' The',
#  ' Authors',
#  ' Asian',
#  ' Paci',
#  ' Society',
#  ' Respirology',
#  '\x0cEpithelial',
#  '-Cadpos',
#  ' While',
#  ' Murine',
#  ' Conse',
#  ' The',
#  ' Regular',
#  ' These',
#  ' Australian',
#  ' Health',
#  ' Medical',
#  ' Research',
#  ' Council',
#  '(Grant',
#  ' Victorian',
#  ' Cancer',
#  ' Agency',
#  ' Ramalho',
#  '-Santos',
#  ' Willenbring',
#  ' On',
#  ' Cell',
#  ' Stem',
#  ' Cell',
#  ' Potten',
#  ' Cell',
#  ' In',
#  ' Mc',
#  ' Isaacson',
#  ' Wright',
#  ' Oxford',
#  ' Textbook',
#  ' Pathology',
#  ' Oxford',
#  ' University',
#  ' Press',
#  ' Rando',
#  ' Stem',
#  ' Moore',
#  ' Overview',
#  ' In',
#  ' Morstyn',
#  ' Sheridan',
#  ' Cell',
#  ' Therapy',
#  ' Stem',
#  ' Transplantation',
#  ' Gene',
#  ' Therapy',
#  ' Cellular',
#  ' Immuno',
#  ' Cambridge',
#  ' University',
#  ' Press',
#  ' New',
#  ' York',
#  ' Marshman',
#  ' Booth',
#  ' Potten',
#  ' The',
#  ' Bioessays',
#  ' Blanpain',
#  ' Horsley',
#  ' Fuchs',
#  ' Epithelial',
#  ' Cell',
#  ' Rawlins',
#  ' Hogan',
#  ' Epithelial',
#  ' Development',
#  ' Brown',
#  ' Rannels',
#  ' Rannels',
#  ' Implications',
#  ' Respir',
#  ' Res',
#  ' Potten',
#  ' Loef',
#  ' Stem',
#  ' Lessons',
#  ' Devel',
#  ' Lajtha',
#  ' Stem',
#  ' Differentiation',
#  ' Jordan',
#  ' Lemischka',
#  ' Clonal',
#  ' Genes',
#  ' Dev',
#  ' Rando',
#  ' The',
#  ' Cell',
#  ' Ho',
#  ' Wagner',
#  ' The',
#  ' Curr',
#  ' Hematol',
#  ' Morrison',
#  ' Kimble',
#  ' Asymmetric',
#  ' Nature',
#  ' Haan',
#  ' Nijhof',
#  ' Van',
#  ' Zant',
#  ' Mouse',
#  ' Blood',
#  ' Avagyan',
#  ' Glouchkova',
#  ' Choi',
#  ' Immunol',
#  ' Henckaerts',
#  ' Langer',
#  ' Snoeck',
#  ' Quantitative',
#  ' Blood',
#  ' Ousset',
#  ' Van',
#  ' Keymeulen',
#  ' Bouvencourt',
#  ' Multipotent',
#  ' Nat',
#  ' Cell',
#  ' Biol',
#  ' Barker',
#  ' Bartfeld',
#  ' Clevers',
#  ' Tissue',
#  ' Cell',
#  ' Stem',
#  ' Cell',
#  ' Barker',
#  ' Epithelial',
#  ' Cell',
#  ' Stem',
#  ' Cell',
#  ' Mc',
#  ' Bertoncello',
#  ' Concise',
#  ' Stem',
#  ' Cells',
#  ' Doupe',
#  ' Alcolea',
#  ' Roshan',
#  ' Science',
#  ' Becher',
#  ' Holland',
#  ' Evidence',
#  ' Genes',
#  ' Stripp',
#  ' Hierarchical',
#  ' Proc',
#  ' Am',
#  ' Thorac',
#  ' Soc',
#  ' Yanger',
#  ' Stanger',
#  ' Facultative',
#  ' Dev',
#  ' Dyn',
#  ' Zhang',
#  ' Li',
#  ' Lee',
#  ' Dedifferentiation',
#  ' PLo',
#  ' The',
#  ' Authors',
#  ' Asian',
#  ' Paci',
#  ' Society',
#  ' Respirology',
#  ' Bertoncello',
#  ' Mc',
#  ' Kubin',
#  ' Poling',
#  ' Kostin',
#  ' Oncostatin',
#  ' Cell',
#  ' Cell',
#  ' Till',
#  ' Regulation',
#  ' In',
#  ' Carnie',
#  ' Lala',
#  ' Osmond',
#  ' Stem',
#  ' Cells',
#  ' Renewing',
#  ' Cell',
#  ' Populations',
#  ' Press',
#  ' Inc',
#  ' New',
#  ' York',
#  ' Lensch',
#  ' An',
#  ' Stem',
#  ' Cell',
#  ' Rev',
#  ' Quesenberry',
#  ' Dooner',
#  ' Goldberg',
#  ' Trans',
#  ' Am',
#  ' Clin',
#  ' Cli',
#  ' Assoc',
#  ' Schier',
#  ' Nodal',
#  ' Ann',
#  ' Rev',
#  ' Biol',
#  ' Wolf',
#  ' Trentin',
#  ' Hemopoietic',
#  ' Effect',
#  ' Exp',
#  ' Med',
#  ' Scho',
#  ' The',
#  ' Blood',
#  ' Cells',
#  ' Nelson',
#  ' Bissell',
#  ' Of',
#  ' Ann',
#  ' Rev',
#  ' Dev',
#  ' Biol',
#  ' Morrison',
#  ' Spradling',
#  ' Stem',
#  ' Cell',
#  ' Scadden',
#  ' The',
#  ' Nature',
#  ' Chen',
#  ' Lewallen',
#  ' Xie',
#  ' Adhesion',
#  ' Development',
#  ' Brody',
#  ' Atkinson',
#  ' Epithelial',
#  ' In',
#  ' Molecular',
#  ' Pathology',
#  ' Lung',
#  ' Diseases',
#  ' Springer',
#  ' York',
#  ' Holgate',
#  ' Davies',
#  ' Lackie',
#  ' Epithelial',
#  ' Allergy',
#  ' Clin',
#  ' Immun',
#  ' Holgate',
#  ' Davies',
#  ' Rethinking',
#  ' Shi',
#  ' Xu',
#  ' Warburton',
#  ' Development',
#  ' Respirology',
#  ' Buckley',
#  ' Shi',
#  ' Carraro',
#  ' The',
#  ' Am',
#  ' Respir',
#  ' Cell',
#  ' Mol',
#  ' Bryder',
#  ' Rossi',
#  ' Weissman',
#  ' Hematopoietic',
#  ' Am',
#  ' Pathol',
#  ' Shackleton',
#  ' Vaillant',
#  ' Simpson',
#  ' Generation',
#  ' Nature',
#  ' Stingl',
#  ' Eirew',
#  ' Ricketson',
#  ' Puri',
#  ' Nature',
#  ' Raiser',
#  ' Kim',
#  ' Commentary',
#  ' Sca',
#  ' Stem',
#  ' Cells',
#  ' Alexander',
#  ' Puchalski',
#  ' Klos',
#  ' Separating',
#  ' Cell',
#  ' Cell',
#  ' Holmes',
#  ' Stanford',
#  ' Concise',
#  ' Stem',
#  ' Cells',
#  ' Grassinger',
#  ' Haylock',
#  ' Williams',
#  ' Phenotypically',
#  ' Blood',
#  ' Roobrouck',
#  ' Vanuytsel',
#  ' Verfaillie',
#  ' Concise',
#  ' Cells',
#  ' Wion',
#  ' Christen',
#  ' Barbier',
#  ' Cell',
#  ' Stem',
#  ' Cell',
#  ' Csaszar',
#  ' Kirouac',
#  ' Yu',
#  ' Rapid',
#  ' Cell',
#  ' Stem',
#  ' Cell',
#  ' Unwin',
#  ' Smith',
#  ' Blinco',
#  ' Quantitative',
#  ' Blood',
#  ' Unwin',
#  ' Whetton',
#  ' Systematic',
#  ' Cell',
#  ' Cycle',
#  ' Habibian',
#  ' Peters',
#  ' Hsieh',
#  ' The',
#  ' Exp',
#  ' Med',
#  ' Matute',
#  '-Bello',
#  ' Downey',
#  ' Moore',
#  ' An',
#  ' Ameri',
#  ' Thoracic',
#  ' Society',
#  ' Am',
#  ' Cell',
#  ' Mol',
#  ' Biol',
#  ' Rawlins',
#  ' Perl',
#  ' The',
#  ' Am',
#  ' Respir',
#  ' Cell',
#  ' Mol',
#  ' Biol',
#  ' Baron',
#  ' Choi',
#  ' Owen',
#  ' Genetically',
#  ' Am',
#  ' Lung',
#  ' Cell',
#  ' Mol',
#  ' Biol',
#  ' Morrisey',
#  ' Hogan',
#  ' Preparing',
#  ' Dev',
#  ' Cell',
#  ' Weiss',
#  ' Bertoncello',
#  ' Borok',
#  ' Stem',
#  ' Proc',
#  ' Am',
#  ' Thorac',
#  ' Soc',
#  ' Weibel',
#  ' What',
#  ' Swiss',
#  ' Med',
#  '.Wkly',
#  ' Rackley',
#  ' Stripp',
#  ' Building',
#  ' Clin',
#  ' Invest',
#  ' Kauffman',
#  ' Cell',
#  ' Int',
#  ' Rev',
#  ' Pathol',
#  ' Bowden',
#  ' Cell',
#  ' Am',
#  ' Rev',
#  ' Respir',
#  ' Dis',
#  ' Beers',
#  ' Morrisey',
#  ' The',
#  ' Clin',
#  ' Invest',
#  ' Bertoncello',
#  ' Mc',
#  ' Endogenous',
#  ' Expert',
#  ' Rev',
#  ' Med',
#  ' Rock',
#  ' Hogan',
#  ' Epithelial',
#  ' Ann',
#  ' Rev',
#  ' Dev',
#  ' Biol',
#  ' Borthwick',
#  ' Shahbazian',
#  ' Krantz',
#  ' Evidence',
#  ' Am',
#  ' Respir',
#  ' Cell',
#  ' Biol',
#  ' Hong',
#  ' Reynolds',
#  ' Watkins',
#  ' Basal',
#  ' Am',
#  ' Pathol',
#  ' Rock',
#  ' Onaitis',
#  ' Rawlins',
#  ' Basal',
#  ' Proc',
#  ' Natl',
#  ' Sci',
#  ' Cole',
#  ' Smith',
#  ' Jenkins',
#  ' Tracheal',
#  ' Am',
#  ' Pathol',
#  ' Hegab',
#  ' Ha',
#  ' Gilbert',
#  ' Novel',
#  ' Stem',
#  ' Cells',
#  ' Reynolds',
#  ' Giangreco',
#  ' Power',
#  ' Neuroepithelial',
#  ' Am',
#  ' Pathol',
#  ' Reynolds',
#  ' Hong',
#  ' Giangreco',
#  ' Conditional',
#  ' Clara',
#  ' Am',
#  ' Physiol',
#  ' Lung',
#  ' Cell',
#  ' Mol',
#  ' Biol',
#  ' Giangreco',
#  ' Reynolds',
#  ' Stripp',
#  ' Terminal',
#  ' The',
#  ' Authors',
#  ' Asian',
#  ' Paci',
#  ' Society',
#  ' Respirology',
#  '\x0cEpithelial',
#  ' Am',
#  ' Pathol',
#  ' Am',
#  ' Physiol',
#  ' Lung',
#  ' Mol',
#  ' Biol',
#  ' Kim',
#  ' Jackson',
#  ' Woolfenden',
#  ' Identi',
#  ' Nolen',
#  '-Walston',
#  ' Kim',
#  ' Mazan',
#  ' Cellular',
#  ' Am',
#  ' Physiol',
#  ' Lung',
#  ' Cell',
#  ' Mol',
#  ' Biol',
#  ' Zacharek',
#  ' Fillmore',
#  ' Lau',
#  ' Lung',
#  ' Cell',
#  ' Stem',
#  ' Cell',
#  ' Adamson',
#  ' Bowden',
#  ' Derivation',
#  ' Lab',
#  ' Invest',
#  ' Evans',
#  ' Cabral',
#  ' Stephens',
#  ' Transformation',
#  ' Exp',
#  ' Pathol',
#  ' Giangreco',
#  ' Arwert',
#  ' Rosewell',
#  ' Stem',
#  ' Natl',
#  ' Acad',
#  ' Sci',
#  ' Teisanu',
#  ' Chen',
#  ' Matsumoto',
#  ' Functional',
#  ' Am',
#  ' Respir',
#  ' Cell',
#  ' Mol',
#  ' Biol',
#  ' Mc',
#  ' Yuen',
#  ' Williams',
#  ' Evidence',
#  ' Proc',
#  ' Acad',
#  ' Sci',
#  ' Chen',
#  ' Matsumoto',
#  ' Brockway',
#  ' Airway',
#  ' Stem',
#  ' Cells',
#  ' Lee',
#  ' Kim',
#  ' Gludish',
#  ' Am',
#  ' Cell',
#  ' Mol',
#  ' Biol',
#  '[EPub',
#  ' Rawlins',
#  ' Okubo',
#  ' Xue',
#  ' The',
#  ' Scgb',
#  ' Clara',
#  ' Cell',
#  ' Stem',
#  ' Cell',
#  ' Ghosh',
#  ' Brechbuhl',
#  ' Smith',
#  ' Context',
#  ' Am',
#  ' Respir',
#  ' Cell',
#  ' Mol',
#  ' Biol',
#  ' Song',
#  ' Yao',
#  ' Lin',
#  ' Functional',
#  ' Proc',
#  ' Natl',
#  ' Acad',
#  ' Sci',
#  ' Tropea',
#  ' Leder',
#  ' Aslam',
#  ' Bronchioalveolar',
#  ' Kumar',
#  ' Hu',
#  ' Yamamoto',
#  ' Distal',
#  ' Cell',
#  ' Chapman',
#  ' Li',
#  ' Alexander',
#  ' Integrin',
#  ' Clin',
#  ' Invest',
#  ' Hynds',
#  ' Giangreco',
#  ' The',
#  ' Cells',
#  ' Bertoncello',
#  ' Bradford',
#  ' Surrogate',
#  ' In',
#  ' Garland',
#  ' Quesenberry',
#  ' Hilton',
#  ' Stimulating',
#  ' Factor',
#  ' Marcel',
#  ' Dekker',
#  ' Inc',
#  ' New',
#  ' Coulombel',
#  ' Identi',
#  ' Oncogene',
#  ' Franzdottir',
#  ' Axelsson',
#  ' Arason',
#  ' Airway',
#  ' Respir',
#  ' Res',
#  ' Wu',
#  ' Peters',
#  '-Hall',
#  ' Bose',
#  ' Human',
#  ' Am',
#  ' Respir',
#  ' Cell',
#  ' Mol',
#  ' Biol',
#  ' Hegab',
#  ' Ha',
#  ' Darmawan',
#  ' Isolation',
#  ' Stem',
#  ' Cells',
#  ' Med',
#  ' Fessart',
#  ' Begueret',
#  ' Delom',
#  ' Respir',
#  '[Epub',
#  ' Oeztuerk',
#  '-Winder',
#  ' Guinot',
#  ' Ochalek',
#  ' Regulation',
#  ' Kajstura',
#  ' Rota',
#  ' Hall',
#  ' Evidence',
#  ' Engl',
#  ' Med',
#  ' Lung',
#  ' Nat',
#  ' Med',
#  ' Kipling',
#  ' Cooke',
#  ' Hypervariable',
#  ' Nature',
#  ' Jungebluth',
#  ' Alici',
#  ' Baiguera',
#  ' Tracheobronchial',
#  ' Lancet',
#  ' The',
#  ' Authors',
#  ' Asian',
#  ' Paci',
#  ' Society',
#  ' Respirology']

# %%
re.findall(r'([article]*/doi/10[.][0-9]{4,}[^\s"/<>]*/[^\s"<>]+)', bio["text"].iloc[10])
# Out:
# []

# %%
for i in range(len(bio)):
    if len(re.findall(r'(/doi/10[.][0-9]{4,}.*)', bio["text"].iloc[i])) > 0:
        print(re.findall(r'(/doi/10[.][0-9]{4,}.*)', bio["text"].iloc[i]))

# [0-9]{4,6} -- ищем строчку, состояющую из цифр (и только из них), длина которой -- минимум 4 и максимум 6
# Out:
# ['/doi/10.1242/dev.02732.']
# ['/doi/10.1242/bio.038232.supplemental']
# ['/doi/10.1046/j.0305-1846.2003.00525.x/abstract.']

# %% [markdown]
# ## Продолжаем работу над текстом

# %%
bio['text'] = bio['text'].astype(str)

# %%
bio_sents = sent_split(bio, "text")
bio_sents
# Out:
#                                                      text
# 0       bs_bs_banner\n\nINVITED REVIEW SERIES:\nSTEM C...
# 1       IVAN BERTONCELLO AND JONATHAN L. MCQUALTER\n\n...
# 2       In this\nreview, we describe the attributes of...
# 3       We describe the power and\nlimitations of expe...
# 4       The review summarizes\nrecent progress and obs...
# ...                                                   ...
# 121159                   Sheth RD, Jin M, Bhut BV, et al.
# 121160  (2014) Affinity precipitation of a monoclonal ...
# 121161               Biotechnol  Bioeng \n111: 1595–1603.
# 121162   © 2015 Rachel Chen, et al., licensee AIMS Press.
# 121163  This is an open \naccess  article  distributed...
#
# [121164 rows x 1 columns]

# %%
clean_bio = cleantext(bio_sents)
clean_bio
# Out:
#                                                      text  \
# 0       bs_bs_banner\n\nINVITED REVIEW SERIES:\nSTEM C...
# 1       IVAN BERTONCELLO AND JONATHAN L. MCQUALTER\n\n...
# 2       In this\nreview, we describe the attributes of...
# 3       We describe the power and\nlimitations of expe...
# 4       The review summarizes\nrecent progress and obs...
# ...                                                   ...
# 121159                   Sheth RD, Jin M, Bhut BV, et al.
# 121160  (2014) Affinity precipitation of a monoclonal ...
# 121161               Biotechnol  Bioeng \n111: 1595–1603.
# 121162   © 2015 Rachel Chen, et al., licensee AIMS Press.
# 121163  This is an open \naccess  article  distributed...
#
#                                              cleaned_text
# 0       bs bs banner invited review series stem cells ...
# 1       ivan bertoncello and jonathan mcqualter lung h...
# 2       in this review we describe the attributes of a...
# 3       we describe the power and limitations of exper...
# 4       the review summarizes recent progress and obst...
# ...                                                   ...
# 121159                      sheth rd jin m bhut bv et al
# 121160   affinity precipitation of a monoclonal antibo...
# 121161                                 biotechnol bioeng
# 121162             rachel chen et al licensee aims press
# 121163  this is an open access article distributed und...
#
# [121164 rows x 2 columns]

# %%
clean_bio.cleaned_text.iloc[1] #просто привели предложения в нормальный вид и выкинули пунктуацию + "непонятные" символы
# Out:
# 'ivan bertoncello and jonathan mcqualter lung health research centre department of pharmacology lung health research centre university of melbourne melbourne victoria australia abstract recognition of the potential of stem cell based therapies for alleviating intractable lung diseases has provided the impetus for research aimed at identifying regenerative cells in the adult lung understanding how they are organized and regulated and how they could be harnessed in lung regenerative medicine '

# %%
remove_biology_terms(clean_bio.iloc[1].cleaned_text) # удаляем биологические термины,
# оставляем при этом академическую лексику - слова литературного языка, которые в научном контексте не только приобретают иную семантику,
# но также являются "субстратом для создания новых терминов" (Лейчик)
# НЕ удаляем / удаляем стоп-слова
# Out:
# 'jonathan health research centre department health research centre university victoria australia potential based alleviating intractable diseases provided impetus research aimed identifying adult understanding could regenerative medicine'

# %%
clean_bio["removed_terms_text"] = clean_bio['cleaned_text'].apply(remove_biology_terms)
clean_bio
# Out:
#                                                      text  \
# 0       bs_bs_banner\n\nINVITED REVIEW SERIES:\nSTEM C...
# 1       IVAN BERTONCELLO AND JONATHAN L. MCQUALTER\n\n...
# 2       In this\nreview, we describe the attributes of...
# 3       We describe the power and\nlimitations of expe...
# 4       The review summarizes\nrecent progress and obs...
# ...                                                   ...
# 121159                   Sheth RD, Jin M, Bhut BV, et al.
# 121160  (2014) Affinity precipitation of a monoclonal ...
# 121161               Biotechnol  Bioeng \n111: 1595–1603.
# 121162   © 2015 Rachel Chen, et al., licensee AIMS Press.
# 121163  This is an open \naccess  article  distributed...
#
#                                              cleaned_text  \
# 0       bs bs banner invited review series stem cells ...
# 1       ivan bertoncello and jonathan mcqualter lung h...
# 2       in this review we describe the attributes of a...
# 3       we describe the power and limitations of exper...
# 4       the review summarizes recent progress and obst...
# ...                                                   ...
# 121159                      sheth rd jin m bhut bv et al
# 121160   affinity precipitation of a monoclonal antibo...
# 121161                                 biotechnol bioeng
# 121162             rachel chen et al licensee aims press
# 121163  this is an open access article distributed und...
#
#                                        removed_terms_text
# 0       bs bs banner invited review series stem cells ...
# 1       and jonathan health research centre department...
# 2       in this review we describe the of adult stem a...
# 3       we describe the power and of strategies and us...
# 4       the review summarizes recent progress and in d...
# ...                                                   ...
# 121159                                        rd bv et al
# 121160    affinity precipitation of a from an harvest ...
# 121161
# 121162                                    chen et al aims
# 121163  this is an open access article distributed und...
#
# [121164 rows x 3 columns]

# %%
prep_bio = clean_long_sent(clean_bio)
prep_bio
# Out:
#                                                      text  \
# 0       bs_bs_banner\n\nINVITED REVIEW SERIES:\nSTEM C...
# 1       IVAN BERTONCELLO AND JONATHAN L. MCQUALTER\n\n...
# 2       In this\nreview, we describe the attributes of...
# 3       We describe the power and\nlimitations of expe...
# 4       The review summarizes\nrecent progress and obs...
# ...                                                   ...
# 121159                   Sheth RD, Jin M, Bhut BV, et al.
# 121160  (2014) Affinity precipitation of a monoclonal ...
# 121161               Biotechnol  Bioeng \n111: 1595–1603.
# 121162   © 2015 Rachel Chen, et al., licensee AIMS Press.
# 121163  This is an open \naccess  article  distributed...
#
#                                              cleaned_text  \
# 0       bs bs banner invited review series stem cells ...
# 1       ivan bertoncello and jonathan mcqualter lung h...
# 2       in this review we describe the attributes of a...
# 3       we describe the power and limitations of exper...
# 4       the review summarizes recent progress and obst...
# ...                                                   ...
# 121159                      sheth rd jin m bhut bv et al
# 121160   affinity precipitation of a monoclonal antibo...
# 121161                                 biotechnol bioeng
# 121162             rachel chen et al licensee aims press
# 121163  this is an open access article distributed und...
#
#                                        removed_terms_text  len
# 0       bs bs banner invited review series stem cells ...  140
# 1       and jonathan health research centre department...  494
# 2       in this review we describe the of adult stem a...  191
# 3       we describe the power and of strategies and us...  214
# 4       the review summarizes recent progress and in d...  161
# ...                                                   ...  ...
# 121159                                        rd bv et al   29
# 121160    affinity precipitation of a from an harvest ...  131
# 121161                                                      18
# 121162                                    chen et al aims   39
# 121163  this is an open access article distributed und...  173
#
# [120445 rows x 4 columns]

# %%
prep_bio.to_csv('prep_SW_BIO.csv')

# %% [markdown]
# # KJV BIBLE
# King James Bible, 1611, канонический перевод Библии, обычно называемый Авторизованной версией (the Authorized Version).
#
# Отказались от использования этой версии перевода Библии (несмотря на все еще лидирующую популярность King James Version), так как она содержит большое количество архаизмов, встретить которые в современных научно-полпулярных текстах мы не ожидаем.

# %%
import pandas as pd
import numpy as np

import re
import string
import nltk
from nltk.corpus import stopwords

nltk.download("stopwords")
stops = stopwords.words("english")

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
bible = pd.read_csv("/content/KJV.csv")
bible
# Out:
#        Unnamed: 0          citation        book  chapter  verse  \
# 0               0       Genesis 1:1     Genesis        1      1
# 1               1       Genesis 1:2     Genesis        1      2
# 2               2       Genesis 1:3     Genesis        1      3
# 3               3       Genesis 1:4     Genesis        1      4
# 4               4       Genesis 1:5     Genesis        1      5
# ...           ...               ...         ...      ...    ...
# 31097       31097  Revelation 22:17  Revelation       22     17
# 31098       31098  Revelation 22:18  Revelation       22     18
# 31099       31099  Revelation 22:19  Revelation       22     19
# 31100       31100  Revelation 22:20  Revelation       22     20
# 31101       31101  Revelation 22:21  Revelation       22     21
#
#                                                     text  book_code  \
# 0      In the beginning God created the heaven and th...          1
# 1      And the earth was without form, and void; and ...          1
# 2      And God said, Let there be light: and there wa...          1
# 3      And God saw the light, that it was good: and G...          1
# 4      And God called the light Day, and the darkness...          1
# ...                                                  ...        ...
# 31097  And the Spirit and the bride say, Come. And le...         66
# 31098  For I testify unto every man that heareth the ...         66
# 31099  And if any man shall take away from the words ...         66
# 31100  He which testifieth these things saith, Surely...         66
# 31101  The grace of our Lord Jesus Christ be with you...         66
#
#            testament  testament_code
# 0      Old Testament               0
# 1      Old Testament               0
# 2      Old Testament               0
# 3      Old Testament               0
# 4      Old Testament               0
# ...              ...             ...
# 31097  New Testament               1
# 31098  New Testament               1
# 31099  New Testament               1
# 31100  New Testament               1
# 31101  New Testament               1
#
# [31102 rows x 9 columns]

# %% [markdown]
# ### Включаем в "библейский" корпус только New Testament. В самом начале исследования была идея использовать только NT, однако в процессе мы от этого отказались, включив в "библейский" корпус оба Завета. Кроме того, решили использовать American Standard Version.

# %%
bible = bible[bible.testament_code == 1]
bible.head()
# Out:
#        Unnamed: 0     citation     book  chapter  verse  \
# 23145       23145  Matthew 1:1  Matthew        1      1
# 23146       23146  Matthew 1:2  Matthew        1      2
# 23147       23147  Matthew 1:3  Matthew        1      3
# 23148       23148  Matthew 1:4  Matthew        1      4
# 23149       23149  Matthew 1:5  Matthew        1      5
#
#                                                     text  book_code  \
# 23145  The book of the generation of Jesus Christ, th...         40
# 23146  Abraham begat Isaac; and Isaac begat Jacob; an...         40
# 23147  And Judas begat Phares and Zara of Thamar; and...         40
# 23148  And Aram begat Aminadab; and Aminadab begat Na...         40
# 23149  And Salmon begat Booz of Rachab; and Booz bega...         40
#
#            testament  testament_code
# 23145  New Testament               1
# 23146  New Testament               1
# 23147  New Testament               1
# 23148  New Testament               1
# 23149  New Testament               1

# %%
def sent_split(df): # просто разбили на предложения!!!
    sents = []
    for _, row in df.iterrows():
        text = row.text
        for sent in nltk.sent_tokenize(text):
            sents.append(sent)
    sents = pd.DataFrame(sents).rename({0: 'text'}, axis=1)
    return sents

# %%
bible_sents = sent_split(bible)

# %%
def clean_bible_text(df):
    # приводим к нижнему регистру
    df['cleaned_text'] = df['text'].str.lower()

    # удаляем символы
    df['cleaned_text'] = df['cleaned_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)

    # Удаление цифр
    df['cleaned_text'] = df['cleaned_text'].replace(r'\d+', '', regex=True)
    return df

# %%
prep_bible = clean_bible_text(bible_sents)

# %%
prep_bible
# Out:
#                                                    text  \
# 0     The book of the generation of Jesus Christ, th...
# 1     Abraham begat Isaac; and Isaac begat Jacob; an...
# 2     And Judas begat Phares and Zara of Thamar; and...
# 3     And Aram begat Aminadab; and Aminadab begat Na...
# 4     And Salmon begat Booz of Rachab; and Booz bega...
# ...                                                 ...
# 9025  He which testifieth these things saith, Surely...
# 9026                                              Amen.
# 9027                         Even so, come, Lord Jesus.
# 9028  The grace of our Lord Jesus Christ be with you...
# 9029                                              Amen.
#
#                                            cleaned_text
# 0     the book of the generation of jesus christ  th...
# 1     abraham begat isaac  and isaac begat jacob  an...
# 2     and judas begat phares and zara of thamar  and...
# 3     and aram begat aminadab  and aminadab begat na...
# 4     and salmon begat booz of rachab  and booz bega...
# ...                                                 ...
# 9025  he which testifieth these things saith  surely...
# 9026                                              amen
# 9027                         even so  come  lord jesus
# 9028  the grace of our lord jesus christ be with you...
# 9029                                              amen
#
# [9030 rows x 2 columns]

# %%
import string

def stopwords_remover(words):

  without_stopwords = ""
  for word in words.split(" "):
    if word in stops or word in string.punctuation:
      continue
    else:
      without_stopwords += word + " "
  return without_stopwords

# %%
prep_bible['prep_text'] = prep_bible['cleaned_text'].apply(stopwords_remover)

# %%
prep_bible
# Out:
#                                                    text  \
# 0     The book of the generation of Jesus Christ, th...
# 1     Abraham begat Isaac; and Isaac begat Jacob; an...
# 2     And Judas begat Phares and Zara of Thamar; and...
# 3     And Aram begat Aminadab; and Aminadab begat Na...
# 4     And Salmon begat Booz of Rachab; and Booz bega...
# ...                                                 ...
# 9025  He which testifieth these things saith, Surely...
# 9026                                              Amen.
# 9027                         Even so, come, Lord Jesus.
# 9028  The grace of our Lord Jesus Christ be with you...
# 9029                                              Amen.
#
#                                            cleaned_text  \
# 0     the book of the generation of jesus christ  th...
# 1     abraham begat isaac  and isaac begat jacob  an...
# 2     and judas begat phares and zara of thamar  and...
# 3     and aram begat aminadab  and aminadab begat na...
# 4     and salmon begat booz of rachab  and booz bega...
# ...                                                 ...
# 9025  he which testifieth these things saith  surely...
# 9026                                              amen
# 9027                         even so  come  lord jesus
# 9028  the grace of our lord jesus christ be with you...
# 9029                                              amen
#
#                                               prep_text
# 0     book generation jesus christ son david son abr...
# 1     abraham begat isaac isaac begat jacob jacob be...
# 2     judas begat phares zara thamar phares begat es...
# 3     aram begat aminadab aminadab begat naasson naa...
# 4     salmon begat booz rachab booz begat obed ruth ...
# ...                                                 ...
# 9025       testifieth things saith surely come quickly
# 9026                                              amen
# 9027                              even come lord jesus
# 9028                           grace lord jesus christ
# 9029                                              amen
#
# [9030 rows x 3 columns]

# %%
def clean_long_sent(df):
    df["len"] = df["prep_text"].apply(lambda x: len(x))
    return df[df.len <= 512]

# %%
prep_bible = clean_long_sent(prep_bible)
prep_bible
# Out:
#                                                    text  \
# 0     The book of the generation of Jesus Christ, th...
# 1     Abraham begat Isaac; and Isaac begat Jacob; an...
# 2     And Judas begat Phares and Zara of Thamar; and...
# 3     And Aram begat Aminadab; and Aminadab begat Na...
# 4     And Salmon begat Booz of Rachab; and Booz bega...
# ...                                                 ...
# 9025  He which testifieth these things saith, Surely...
# 9026                                              Amen.
# 9027                         Even so, come, Lord Jesus.
# 9028  The grace of our Lord Jesus Christ be with you...
# 9029                                              Amen.
#
#                                            cleaned_text  \
# 0     the book of the generation of jesus christ  th...
# 1     abraham begat isaac  and isaac begat jacob  an...
# 2     and judas begat phares and zara of thamar  and...
# 3     and aram begat aminadab  and aminadab begat na...
# 4     and salmon begat booz of rachab  and booz bega...
# ...                                                 ...
# 9025  he which testifieth these things saith  surely...
# 9026                                              amen
# 9027                         even so  come  lord jesus
# 9028  the grace of our lord jesus christ be with you...
# 9029                                              amen
#
#                                               prep_text  len
# 0     book generation jesus christ son david son abr...   51
# 1     abraham begat isaac isaac begat jacob jacob be...   65
# 2     judas begat phares zara thamar phares begat es...   67
# 3     aram begat aminadab aminadab begat naasson naa...   64
# 4     salmon begat booz rachab booz begat obed ruth ...   63
# ...                                                 ...  ...
# 9025       testifieth things saith surely come quickly    44
# 9026                                              amen     5
# 9027                              even come lord jesus    21
# 9028                           grace lord jesus christ    24
# 9029                                              amen     5
#
# [9030 rows x 4 columns]

# %%
prep_bible[prep_bible.prep_text != 'amen ']
# Out:
#                                                    text  \
# 0     The book of the generation of Jesus Christ, th...
# 1     Abraham begat Isaac; and Isaac begat Jacob; an...
# 2     And Judas begat Phares and Zara of Thamar; and...
# 3     And Aram begat Aminadab; and Aminadab begat Na...
# 4     And Salmon begat Booz of Rachab; and Booz bega...
# ...                                                 ...
# 9023  For I testify unto every man that heareth the ...
# 9024  And if any man shall take away from the words ...
# 9025  He which testifieth these things saith, Surely...
# 9027                         Even so, come, Lord Jesus.
# 9028  The grace of our Lord Jesus Christ be with you...
#
#                                            cleaned_text  \
# 0     the book of the generation of jesus christ  th...
# 1     abraham begat isaac  and isaac begat jacob  an...
# 2     and judas begat phares and zara of thamar  and...
# 3     and aram begat aminadab  and aminadab begat na...
# 4     and salmon begat booz of rachab  and booz bega...
# ...                                                 ...
# 9023  for i testify unto every man that heareth the ...
# 9024  and if any man shall take away from the words ...
# 9025  he which testifieth these things saith  surely...
# 9027                         even so  come  lord jesus
# 9028  the grace of our lord jesus christ be with you...
#
#                                               prep_text  len
# 0     book generation jesus christ son david son abr...   51
# 1     abraham begat isaac isaac begat jacob jacob be...   65
# 2     judas begat phares zara thamar phares begat es...   67
# 3     aram begat aminadab aminadab begat naasson naa...   64
# 4     salmon begat booz rachab booz begat obed ruth ...   63
# ...                                                 ...  ...
# 9023  testify unto every man heareth words prophecy ...  117
# 9024  man shall take away words book prophecy god sh...  105
# 9025       testifieth things saith surely come quickly    44
# 9027                              even come lord jesus    21
# 9028                           grace lord jesus christ    24
#
# [8987 rows x 4 columns]

# %%
prep_bible.to_csv('prep_KJV.csv')

# %% [markdown]
# # American Standard Version (asb - в нашем исследовании)
# * Пересмотр the Authorised Version (King James Bible) произошел благодаря сделанным с  XVII в. многочисленным открытиям  в области древних манускриптов. Основные принципы нового перевода состояли в следующем: как можно меньше изменять текст the Authorised Version, максимально ограничить воздействие таких изменений на язык the Authorised Version и более ранних версий; адаптировать текст к современному (конец ХIX - начало ХХ вв.) состоянию языка. Обновленная редакции вышла в Англии в 1881 г. (Новый Завет) и 1885 г. (Ветхий Завет). В Америке этот же перевод появился в 1901 году под названием Американская стандартная версия (American Standard Version).
#
# Форостенко, А В. Топология современных переводов Библии на английский язык. Дисс. ... канд. филол. наук. М., 2003.

# %%
import pandas as pd
import numpy as np

import re
import string
import nltk
from nltk.corpus import stopwords

nltk.download("stopwords")
stops = stopwords.words("english")

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
asb = pd.read_csv('/content/asb.csv')
asb
# Out:
#        Verse ID   Book Name  Book Number  Chapter  Verse  \
# 0             1     Genesis            1        1      1
# 1             2     Genesis            1        1      2
# 2             3     Genesis            1        1      3
# 3             4     Genesis            1        1      4
# 4             5     Genesis            1        1      5
# ...         ...         ...          ...      ...    ...
# 31097     31098  Revelation           66       22     17
# 31098     31099  Revelation           66       22     18
# 31099     31100  Revelation           66       22     19
# 31100     31101  Revelation           66       22     20
# 31101     31102  Revelation           66       22     21
#
#                                                     Text
# 0      In the beginning God created the heavens and t...
# 1      And the earth was waste and void; and darkness...
# 2      And God said, Let there be light: and there wa...
# 3      And God saw the light, that it was good: and G...
# 4      And God called the light Day, and the darkness...
# ...                                                  ...
# 31097  And the Spirit and the bride say, Come. And he...
# 31098  I testify unto every man that heareth the word...
# 31099  and if any man shall take away from the words ...
# 31100  He who testifieth these things saith, Yea: I c...
# 31101  The grace of the Lord Jesus be with the saints...
#
# [31102 rows x 6 columns]

# %%
asb.iloc[29]['Text']
# Out:
# 'and to every beast of the earth, and to every bird of the heavens, and to everything that creepeth upon the earth, wherein there is life, [I have given] every green herb for food: and it was so.'

# %%
def sent_split(df, col):
    sents = []
    for _, row in df.iterrows():
        text = row[col]
        for sent in nltk.sent_tokenize(text):
            sents.append(sent)
    sents = pd.DataFrame(sents).rename({0: 'Text'}, axis=1)
    return sents

# %%
asb['Text'] = asb['Text'].astype(str)

# %%
asb_sents = sent_split(asb, "Text")

# %%
def clean_bible_text(df):
    # приводим к нижнему регистру
    df['cleaned_text'] = df['Text'].str.lower()

    # удаляем символы
    df['cleaned_text'] = df['cleaned_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)

    # Удаление цифр
    df['cleaned_text'] = df['cleaned_text'].replace(r'\d+', '', regex=True)
    return df

# %%
prep_bible = clean_bible_text(asb_sents)

# %%
prep_bible
# Out:
#                                                     Text  \
# 0      In the beginning God created the heavens and t...
# 1      And the earth was waste and void; and darkness...
# 2      And God said, Let there be light: and there wa...
# 3      And God saw the light, that it was good: and G...
# 4      And God called the light Day, and the darkness...
# ...                                                  ...
# 35345  and if any man shall take away from the words ...
# 35346  He who testifieth these things saith, Yea: I c...
# 35347                            Amen: come, Lord Jesus.
# 35348    The grace of the Lord Jesus be with the saints.
# 35349                                              Amen.
#
#                                             cleaned_text
# 0      in the beginning god created the heavens and t...
# 1      and the earth was waste and void  and darkness...
# 2      and god said  let there be light  and there wa...
# 3      and god saw the light  that it was good  and g...
# 4      and god called the light day  and the darkness...
# ...                                                  ...
# 35345  and if any man shall take away from the words ...
# 35346  he who testifieth these things saith  yea  i c...
# 35347                            amen  come  lord jesus
# 35348    the grace of the lord jesus be with the saints
# 35349                                              amen
#
# [35350 rows x 2 columns]

# %%
# решили не удалять стоп-слова
"""
import string

def stopwords_remover(words):

  without_stopwords = ""
  for word in words.split(" "):
    if word in stops or word in string.punctuation:
      continue
    else:
      without_stopwords += word + " "
  return without_stopwords
  """

# %%
# prep_bible['prep_text'] = prep_bible['cleaned_text'].apply(stopwords_remover)

# %%
prep_bible['prep_text'] = prep_bible['cleaned_text']

# %%
prep_bible
# Out:
#                                                     Text  \
# 0      In the beginning God created the heavens and t...
# 1      And the earth was waste and void; and darkness...
# 2      And God said, Let there be light: and there wa...
# 3      And God saw the light, that it was good: and G...
# 4      And God called the light Day, and the darkness...
# ...                                                  ...
# 35345  and if any man shall take away from the words ...
# 35346  He who testifieth these things saith, Yea: I c...
# 35347                            Amen: come, Lord Jesus.
# 35348    The grace of the Lord Jesus be with the saints.
# 35349                                              Amen.
#
#                                             cleaned_text  \
# 0      in the beginning god created the heavens and t...
# 1      and the earth was waste and void  and darkness...
# 2      and god said  let there be light  and there wa...
# 3      and god saw the light  that it was good  and g...
# 4      and god called the light day  and the darkness...
# ...                                                  ...
# 35345  and if any man shall take away from the words ...
# 35346  he who testifieth these things saith  yea  i c...
# 35347                            amen  come  lord jesus
# 35348    the grace of the lord jesus be with the saints
# 35349                                              amen
#
#                                                prep_text
# 0      in the beginning god created the heavens and t...
# 1      and the earth was waste and void  and darkness...
# 2      and god said  let there be light  and there wa...
# 3      and god saw the light  that it was good  and g...
# 4      and god called the light day  and the darkness...
# ...                                                  ...
# 35345  and if any man shall take away from the words ...
# 35346  he who testifieth these things saith  yea  i c...
# 35347                            amen  come  lord jesus
# 35348    the grace of the lord jesus be with the saints
# 35349                                              amen
#
# [35350 rows x 3 columns]

# %%
def clean_long_sent(df):
    df["len"] = df["prep_text"].apply(lambda x: len(x))
    return df[df.len <= 512]

# %%
prep_bible = clean_long_sent(prep_bible)
prep_bible
# Out:
#                                                     Text  \
# 0      In the beginning God created the heavens and t...
# 1      And the earth was waste and void; and darkness...
# 2      And God said, Let there be light: and there wa...
# 3      And God saw the light, that it was good: and G...
# 4      And God called the light Day, and the darkness...
# ...                                                  ...
# 35345  and if any man shall take away from the words ...
# 35346  He who testifieth these things saith, Yea: I c...
# 35347                            Amen: come, Lord Jesus.
# 35348    The grace of the Lord Jesus be with the saints.
# 35349                                              Amen.
#
#                                             cleaned_text  \
# 0      in the beginning god created the heavens and t...
# 1      and the earth was waste and void  and darkness...
# 2      and god said  let there be light  and there wa...
# 3      and god saw the light  that it was good  and g...
# 4      and god called the light day  and the darkness...
# ...                                                  ...
# 35345  and if any man shall take away from the words ...
# 35346  he who testifieth these things saith  yea  i c...
# 35347                            amen  come  lord jesus
# 35348    the grace of the lord jesus be with the saints
# 35349                                              amen
#
#                                                prep_text  len
# 0      in the beginning god created the heavens and t...   55
# 1      and the earth was waste and void  and darkness...  134
# 2      and god said  let there be light  and there wa...   54
# 3      and god saw the light  that it was good  and g...   85
# 4      and god called the light day  and the darkness...   63
# ...                                                  ...  ...
# 35345  and if any man shall take away from the words ...  185
# 35346  he who testifieth these things saith  yea  i c...   58
# 35347                            amen  come  lord jesus    23
# 35348    the grace of the lord jesus be with the saints    47
# 35349                                              amen     5
#
# [35350 rows x 4 columns]

# %%
prep_bible[prep_bible.prep_text != 'amen ']
# Out:
#                                                     Text  \
# 0      The book of the genealogy of Jesus Christ, the...
# 1                    Abraham became the father of Isaac.
# 2                      Isaac became the father of Jacob.
# 3      Jacob became the father of Judah and his broth...
# 4      Judah became the father of Perez and Zerah by ...
# ...                                                  ...
# 10590  I testify to everyone who hears the words of t...
# 10591  If anyone takes away from the words of the boo...
# 10592  He who testifies these things says, "Yes, I co...
# 10594                             Yes, come, Lord Jesus.
# 10595  The grace of the Lord Jesus Christ be with all...
#
#                                             cleaned_text  \
# 0      the book of the genealogy of jesus christ  the...
# 1                    abraham became the father of isaac
# 2                      isaac became the father of jacob
# 3      jacob became the father of judah and his broth...
# 4      judah became the father of perez and zerah by ...
# ...                                                  ...
# 10590  i testify to everyone who hears the words of t...
# 10591  if anyone takes away from the words of the boo...
# 10592  he who testifies these things says   yes  i co...
# 10594                             yes  come  lord jesus
# 10595  the grace of the lord jesus christ be with all...
#
#                                                prep_text  len
# 0      book genealogy jesus christ son david son abra...   50
# 1                           abraham became father isaac    28
# 2                             isaac became father jacob    26
# 3                    jacob became father judah brothers    35
# 4                 judah became father perez zerah tamar    38
# ...                                                  ...  ...
# 10590  testify everyone hears words prophecy book any...   88
# 10591  anyone takes away words book prophecy may god ...   94
# 10592            testifies things says yes come quickly    39
# 10594                               yes come lord jesus    20
# 10595                    grace lord jesus christ saints    31
#
# [10555 rows x 4 columns]

# %%
prep_bible.to_csv('prep_asb_SW.csv') # American Standard Bible with stop-words

# %% [markdown]
# # Корпус статей из журнала "The Economist"

# %%
df = pd.read_csv("/content/bio_Economist.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 957           957         957
# 958           958         958
# 959           959         959
# 960           960         960
# 961           961         961
#
#                                                   text  \
# 0    FOR THE past four billion years or so the only...
# 1    IN A former leatherworks just off Euston Road ...
# 2    “How many cells are there in a human being?” I...
# 3    LIVING creatures are jolly useful. Farmers rea...
# 4    A broken brain, hidden inside a skull, is hard...
# ..                                                 ...
# 957  Science can be a little scary. Its potential t...
# 958  IT MAY challenge the spirit to think of caulif...
# 959  MAJOR DEPRESSION is a serious illness, but als...
# 960  Holt StudiosA beautiful crop of plasticAt the ...
# 961  ONE of the most valuable weapons in the war on...
#
#                                                  title            date  \
# 0          The promise and perils of synthetic biology    Apr 4th 2019
# 1    Will artificial intelligence help to crack bio...    Jan 7th 2017
# 2    The idea of “holobionts” represents a paradigm...   Jun 14th 2023
# 3          The remarkable promise of cell-free biology    May 4th 2017
# 4    Better brain biology will deliver better medic...   Sep 21st 2022
# ..                                                 ...             ...
# 957                                Towards immortality   Nov 16th 2006
# 958                           The king of cauliflowers   Feb 12th 2015
# 959  A blood test may help the diagnosis and treatm...    May 6th 2021
# 960                            Meet industrial biotech   Nov 20th 2003
# 961       Growing anti-malaria drugs in tobacco plants   Oct 20th 2016
#
#                                                   link
# 0    https://www.economist.com/leaders/2019/04/04/t...
# 1    https://www.economist.com/science-and-technolo...
# 2    https://www.economist.com/science-and-technolo...
# 3    https://www.economist.com/leaders/2017/05/04/t...
# 4    https://www.economist.com/technology-quarterly...
# ..                                                 ...
# 957  https://www.economist.com/news/2006/11/16/towa...
# 958  https://www.economist.com/middle-east-and-afri...
# 959  https://www.economist.com/science-and-technolo...
# 960  https://www.economist.com/news/2003/11/20/meet...
# 961  https://www.economist.com/science-and-technolo...
#
# [962 rows x 6 columns]

# %%
df_sents = sent_split(df, 'text')

# %%
df_sents
# Out:
#                                                     Text
# 0      FOR THE past four billion years or so the only...
# 1      Sometimes the gene would be damaged or scrambl...
# 2      From that raw material arose the glories of na...
# 3      But beneath it all, gene begat gene.That is no...
# 4      Now genes can be written from scratch and edit...
# ...                                                  ...
# 35972  He found that, after 15 days, parasite loads i...
# 35973  Dr Kumar plans to try—though he will use genet...
# 35974  But many, probably most, doctors are suspiciou...
# 35975  Dr Kumar’s findings are, nevertheless, interes...
# 35976  And regardless of whether his experiments in h...
#
# [35977 rows x 1 columns]

# %%
def cleantext(df):
    # удаляем имена из одной буквы и точки
    df['cleaned_text'] = df['Text'].replace(r'[A-Z]\.', "", regex=True)
    # приводим к нижнему регистру
    df['cleaned_text'] = df['cleaned_text'].str.lower()

    # Внутритекстовые ссылки в квадратных скобках
    df['cleaned_text'] = df['cleaned_text'].replace(r'\[[0-9 ,– -]+\]', "", regex=True) # от ссылок в квадратных скобках внутри текста

    # Удаление дефиса
    df['cleaned_text'] = df['cleaned_text'].replace(r"-\n", "", regex = True)

    # удаляем всё, кроме заглавных и строчных букв английского алфавита
    df['cleaned_text'] = df['cleaned_text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)

    # Удаление doi | DOI
    df['cleaned_text'] = df['cleaned_text'].replace(r'(/doi/10[.][0-9]{4,}.*)', '', regex=True)

    # удаляем возможные ссылки URL(x):
    df['cleaned_text']  = df['cleaned_text'].replace(r'https.*', "", regex = True)

    # Удаление цифр
    df['cleaned_text'] = df['cleaned_text'].replace(r'\d+', '', regex=True)

    # Удаление двух и более подряд идущих пробелов
    df['cleaned_text'] = df['cleaned_text'].replace(r'\s{2,}', ' ', regex=True)
    return df

# %%
cleaned_df = cleantext(df_sents)

# %%
cleaned_df
# Out:
#                                                     Text  \
# 0      FOR THE past four billion years or so the only...
# 1      Sometimes the gene would be damaged or scrambl...
# 2      From that raw material arose the glories of na...
# 3      But beneath it all, gene begat gene.That is no...
# 4      Now genes can be written from scratch and edit...
# ...                                                  ...
# 35972  He found that, after 15 days, parasite loads i...
# 35973  Dr Kumar plans to try—though he will use genet...
# 35974  But many, probably most, doctors are suspiciou...
# 35975  Dr Kumar’s findings are, nevertheless, interes...
# 35976  And regardless of whether his experiments in h...
#
#                                             cleaned_text
# 0      for the past four billion years or so the only...
# 1      sometimes the gene would be damaged or scrambl...
# 2      from that raw material arose the glories of na...
# 3      but beneath it all gene begat gene that is no ...
# 4      now genes can be written from scratch and edit...
# ...                                                  ...
# 35972  he found that after days parasite loads in ani...
# 35973  dr kumar plans to try though he will use genet...
# 35974  but many probably most doctors are suspicious ...
# 35975  dr kumar s findings are nevertheless interesting
# 35976  and regardless of whether his experiments in h...
#
# [35977 rows x 2 columns]

# %%
def clean_long_sent(df):
    df["len"] = df["cleaned_text"].apply(lambda x: len(x))
    return df[df.len <= 512]

cleaned_df = clean_long_sent(cleaned_df)

# %%
cleaned_df
# Out:
#                                                     Text  \
# 0      FOR THE past four billion years or so the only...
# 1      Sometimes the gene would be damaged or scrambl...
# 2      From that raw material arose the glories of na...
# 3      But beneath it all, gene begat gene.That is no...
# 4      Now genes can be written from scratch and edit...
# ...                                                  ...
# 35972  He found that, after 15 days, parasite loads i...
# 35973  Dr Kumar plans to try—though he will use genet...
# 35974  But many, probably most, doctors are suspiciou...
# 35975  Dr Kumar’s findings are, nevertheless, interes...
# 35976  And regardless of whether his experiments in h...
#
#                                             cleaned_text  len
# 0      for the past four billion years or so the only...  154
# 1      sometimes the gene would be damaged or scrambl...   96
# 2      from that raw material arose the glories of na...   62
# 3      but beneath it all gene begat gene that is no ...   58
# 4      now genes can be written from scratch and edit...   90
# ...                                                  ...  ...
# 35972  he found that after days parasite loads in ani...  269
# 35973  dr kumar plans to try though he will use genet...  137
# 35974  but many probably most doctors are suspicious ...  165
# 35975  dr kumar s findings are nevertheless interesting    49
# 35976  and regardless of whether his experiments in h...  188
#
# [35852 rows x 3 columns]

# %%
"""
import string

def stopwords_remover(words):

  without_stopwords = ""
  for word in words.split(" "):
    if word in stops or word in string.punctuation:
      continue
    else:
      without_stopwords += word + " "
  return without_stopwords
"""

# %%
cleaned_df.loc[:, 'cleaned_text'] = cleaned_df['cleaned_text'].astype(str)

# %%
#cleaned_df.loc[:, 'cleaned_text'] = cleaned_df['cleaned_text'].apply(stopwords_remover)

# %%
cleaned_df
# Out:
#                                                     Text  \
# 0      FOR THE past four billion years or so the only...
# 1      Sometimes the gene would be damaged or scrambl...
# 2      From that raw material arose the glories of na...
# 3      But beneath it all, gene begat gene.That is no...
# 4      Now genes can be written from scratch and edit...
# ...                                                  ...
# 35972  He found that, after 15 days, parasite loads i...
# 35973  Dr Kumar plans to try—though he will use genet...
# 35974  But many, probably most, doctors are suspiciou...
# 35975  Dr Kumar’s findings are, nevertheless, interes...
# 35976  And regardless of whether his experiments in h...
#
#                                             cleaned_text  len
# 0      for the past four billion years or so the only...  154
# 1      sometimes the gene would be damaged or scrambl...   96
# 2      from that raw material arose the glories of na...   62
# 3      but beneath it all gene begat gene that is no ...   58
# 4      now genes can be written from scratch and edit...   90
# ...                                                  ...  ...
# 35972  he found that after days parasite loads in ani...  269
# 35973  dr kumar plans to try though he will use genet...  137
# 35974  but many probably most doctors are suspicious ...  165
# 35975  dr kumar s findings are nevertheless interesting    49
# 35976  and regardless of whether his experiments in h...  188
#
# [35852 rows x 3 columns]

# %%
cleaned_df.to_csv('prep_bio_Economist_SW.csv')
